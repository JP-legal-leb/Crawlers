# %%
import os
import re
import time
import json
import requests
from datetime import datetime

print("Starting document metadata scraping...")

# --- Configuration ---
BASE_API_URL = "https://ncar.gov.sa/api/index.php/api/documents/document-search"
BASE_PDF_URL_PREFIX = "https://ncar.gov.sa/api/index.php/resource/"
BASE_PDF_URL_SUFFIX = "/Documents/OriginalAttachPath"
PDF_OUTPUT_DIR = "NCAR_PDFs"

ITEMS_PER_PAGE = 10
SORT_BY = "approveDate"
SORT_ORDER = "DESC"
START_PAGE = 1 # MODIFY START_PAGE AND END_PAGE, PAGE 1 IS MOST RECENT
END_PAGE = 3 # MODIFY START_PAGE AND END_PAGE, PAGE 1 IS MOST RECENT
REQUEST_DELAY = 0.5  # polite delay

HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36",
    "Referer": "https://ncar.gov.sa/rules-regulations"
}

BASE_PAYLOAD = {
    "approveTool_id": None,
    "documentCategory_id": None,
    "name": None,
    "ApproveDate": None,
    "PublishingStatus": None,
    "alphabeticalCategory_id": None,
    "alphabeticalSubCategory_id": [],
    "alphabeticalTopic_id": None,
    "approveDate_from": None,
    "approveDate_to": None,
    "generalCategory_id": [],
    "governmentalAgency_childId": [],
    "governmentalAgency_id": None,
    "identical": 1,
    "is_printed": None,
    "is_translated": None,
    "is_valid": None,
    "number": None,
    "omAlQourah_date": None,
    "omAlQourah_version": None,
    "particularCategory_id": [],
    "releaseOrgId": None
}


# --- Helpers ---
def sanitize_filename(name: str, max_length: int = 100) -> str:
    """Clean a string for safe filename use."""
    try:
        name = name.encode('latin1').decode('unicode_escape')
    except (UnicodeEncodeError, UnicodeDecodeError):
        pass
    s = re.sub(r"[^\w\s-]", "", name).strip()
    s = re.sub(r"[\s]+", "-", s)
    return s[:max_length] or "untitled"


def fetch_page(page_num: int, payload: dict) -> dict | None:
    """Fetch a single page of documents."""
    url = f"{BASE_API_URL}/{page_num}/{ITEMS_PER_PAGE}/{SORT_BY}/{SORT_ORDER}"
    print(f"🔎 Requesting page {page_num} ...")
    try:
        response = requests.post(url, headers=HEADERS, json=payload, timeout=15)
        response.raise_for_status()
        return response.json()
    except requests.RequestException as e:
        print(f"❌ Error fetching page {page_num}: {e}")
        return None


def save_json(data: list, start: int, end: int) -> str:
    """Save scraped data to JSON with page range + formatted date in filename."""
    os.makedirs("output", exist_ok=True)
    today = datetime.now()
    today_str = f"{today.day:02}.{today.month:02}.{today.year}"  # e.g., 09.12.2024
    filename = f"output/ncar_crawl_page{start}-{end}_({today_str}).json"
    with open(filename, "w", encoding="utf-8") as f:
        json.dump(data, f, ensure_ascii=False, indent=2)
    return filename


def download_pdf(doc: dict, index: int, total: int) -> bool:
    """Download a single PDF if available."""
    encrypted_id = doc.get("id")
    if not encrypted_id:
        print(f"⚠️  Skipping {index+1}/{total}: missing ID")
        return False

    pdf_url = f"{BASE_PDF_URL_PREFIX}{encrypted_id}{BASE_PDF_URL_SUFFIX}"
    title = sanitize_filename(doc.get("title_en", f"document_{index+1}"))
    number = sanitize_filename(doc.get("number", "")) if doc.get("number") else ""
    filename_base = f"{title}_{number}" if number else title

    os.makedirs(PDF_OUTPUT_DIR, exist_ok=True)
    pdf_path = os.path.join(PDF_OUTPUT_DIR, f"{filename_base}.pdf")

    print(f"⬇️  Downloading ({index+1}/{total}): {filename_base}")

    try:
        with requests.get(pdf_url, headers=HEADERS, stream=True, timeout=30) as r:
            r.raise_for_status()
            if "application/pdf" not in r.headers.get("Content-Type", ""):
                print(f"⚠️  Not a PDF ({r.headers.get('Content-Type')}). Skipping.")
                return False

            with open(pdf_path, "wb") as f:
                for chunk in r.iter_content(chunk_size=8192):
                    f.write(chunk)
        print(f"✅ Saved: {pdf_path}")
        return True

    except requests.RequestException as e:
        print(f"❌ Error downloading '{filename_base}': {e}")
        return False


# --- Scraping Process ---
scraped_data = []
for page in range(START_PAGE, END_PAGE + 1):
    page_data = fetch_page(page, BASE_PAYLOAD)
    if not page_data or not page_data.get("data"):
        print(f"⚠️  No data on page {page}, stopping.")
        break
    scraped_data.extend(page_data["data"])
    time.sleep(REQUEST_DELAY)

print(f"\n📊 Scraping complete. Total documents: {len(scraped_data)}")

if scraped_data:
    json_file = save_json(scraped_data, START_PAGE, END_PAGE)
    print(f"💾 Data saved to: {json_file}")

    print("\n🚀 Starting PDF downloads...")
    downloaded = sum(download_pdf(doc, i, len(scraped_data))
                     for i, doc in enumerate(scraped_data))
    print(f"\n🎉 PDF download complete: {downloaded}/{len(scraped_data)} successful.")
else:
    print("⚠️  No data scraped, skipping PDF downloads.")
# Out:
# Starting document metadata scraping...
# 🔎 Requesting page 1 ...
# 🔎 Requesting page 2 ...
# 🔎 Requesting page 3 ...
#
# 📊 Scraping complete. Total documents: 30
# 💾 Data saved to: output/ncar_crawl_page1-3_(23.09.2025).json
#
# 🚀 Starting PDF downloads...
# ⬇️  Downloading (1/30): آلية-مشاركة-الجهات-الحكومية-في-معارض-الكتاب-الدولية-لعام-1447هـ_24939
# ✅ Saved: NCAR_PDFs\آلية-مشاركة-الجهات-الحكومية-في-معارض-الكتاب-الدولية-لعام-1447هـ_24939.pdf
# ⬇️  Downloading (2/30): إضافة-صلاحية-تحديد-المقابل-المالي-لعمل-المرافقين-والمرافقات-للعمالة-الوافدة-النظامية-في-المملكة-لوزي_229
# ✅ Saved: NCAR_PDFs\إضافة-صلاحية-تحديد-المقابل-المالي-لعمل-المرافقين-والمرافقات-للعمالة-الوافدة-النظامية-في-المملكة-لوزي_229.pdf
# ⬇️  Downloading (3/30): تعديل-الفقرة-1-من-المادة-4-من-تنظيم-هيئة-المدن-والمناطق-الاقتصادية-الخاصة-لعام-1431هـ_أ76
# ✅ Saved: NCAR_PDFs\تعديل-الفقرة-1-من-المادة-4-من-تنظيم-هيئة-المدن-والمناطق-الاقتصادية-الخاصة-لعام-1431هـ_أ76.pdf
# ⬇️  Downloading (4/30): تنظيم-المركز-الوطني-لسلامة-النقل-لعام-1447هـ_212
# ✅ Saved: NCAR_PDFs\تنظيم-المركز-الوطني-لسلامة-النقل-لعام-1447هـ_212.pdf
# ⬇️  Downloading (5/30): إضافة-ممثل-لكل-من-هيئة-تنمية-البحث-والتطوير-والابتكار-وهيئة-فنون-الطهي-والهيئة-العامة-للأمن-الغذائي-_216
# ✅ Saved: NCAR_PDFs\إضافة-ممثل-لكل-من-هيئة-تنمية-البحث-والتطوير-والابتكار-وهيئة-فنون-الطهي-والهيئة-العامة-للأمن-الغذائي-_216.pdf
# ⬇️  Downloading (6/30): نظام-نزع-ملكية-العقارات-للمصلحة-العامة-ووضع-اليد-المؤقت-على-العقارات-لعام-1447هـ_م56
# ✅ Saved: NCAR_PDFs\نظام-نزع-ملكية-العقارات-للمصلحة-العامة-ووضع-اليد-المؤقت-على-العقارات-لعام-1447هـ_م56.pdf
# ⬇️  Downloading (7/30): إنشاء-فرع-لجامعة-الأعمال-والتكنولوجيا-الأهلية-بمحافظة-ينبع_198
# ✅ Saved: NCAR_PDFs\إنشاء-فرع-لجامعة-الأعمال-والتكنولوجيا-الأهلية-بمحافظة-ينبع_198.pdf
# ⬇️  Downloading (8/30): قواعد-تحديد-درجات-إركاب-الموظفين-والعاملين-في-الأجهزة-العامة-من-مدنيين-وعسكريين-لعام-1447هـ_196
# ✅ Saved: NCAR_PDFs\قواعد-تحديد-درجات-إركاب-الموظفين-والعاملين-في-الأجهزة-العامة-من-مدنيين-وعسكريين-لعام-1447هـ_196.pdf
# ⬇️  Downloading (9/30): تحديد-النطاق-الجغرافي-لمحمية-مجامع-الهضب_197
# ✅ Saved: NCAR_PDFs\تحديد-النطاق-الجغرافي-لمحمية-مجامع-الهضب_197.pdf
# ⬇️  Downloading (10/30): إحلال-عبارة-وزارة-البلديات-والإسكان-محل-عبارة-وزارة-الشؤون-البلدية-والقروية-والإسكان-وإحلال-عبارة-وز_181
# ✅ Saved: NCAR_PDFs\إحلال-عبارة-وزارة-البلديات-والإسكان-محل-عبارة-وزارة-الشؤون-البلدية-والقروية-والإسكان-وإحلال-عبارة-وز_181.pdf
# ⬇️  Downloading (11/30): نظام-الحرف-والصناعات-اليدوية-لعام-1447هـ_م49
# ✅ Saved: NCAR_PDFs\نظام-الحرف-والصناعات-اليدوية-لعام-1447هـ_م49.pdf
# ⬇️  Downloading (12/30): يجوز-لوزير-التجارة-في-الحالات-التي-يقدرها-تعيين-جميع-أعضاء-مجلس-إدارة-الغرفة-التجارية_م51
# ✅ Saved: NCAR_PDFs\يجوز-لوزير-التجارة-في-الحالات-التي-يقدرها-تعيين-جميع-أعضاء-مجلس-إدارة-الغرفة-التجارية_م51.pdf
# ⬇️  Downloading (13/30): تعديل-المادة-74-من-نظام-المرور-لعام-1428هـ_م50
# ✅ Saved: NCAR_PDFs\تعديل-المادة-74-من-نظام-المرور-لعام-1428هـ_م50.pdf
# ⬇️  Downloading (14/30): تولي-هيئة-التراث-تنظيم-نشاط-الحرف-والصناعات-اليدوية-وفقا-لما-يحدده-نظام-الحرف-والصناعات-اليدوية_157
# ✅ Saved: NCAR_PDFs\تولي-هيئة-التراث-تنظيم-نشاط-الحرف-والصناعات-اليدوية-وفقا-لما-يحدده-نظام-الحرف-والصناعات-اليدوية_157.pdf
# ⬇️  Downloading (15/30): الاشتراطات-البلدية-لتصريح-إشغال-رصيف-لعام-1447هـ_14700073988
# ✅ Saved: NCAR_PDFs\الاشتراطات-البلدية-لتصريح-إشغال-رصيف-لعام-1447هـ_14700073988.pdf
# ⬇️  Downloading (16/30): إضافة-فقرة-إلى-البند-ثالثا-من-إعادة-تنظيم-إجراءات-عملية-نشر-الأنظمة-في-الجريدة-الرسمية-لعام-1425هـ_159
# ✅ Saved: NCAR_PDFs\إضافة-فقرة-إلى-البند-ثالثا-من-إعادة-تنظيم-إجراءات-عملية-نشر-الأنظمة-في-الجريدة-الرسمية-لعام-1425هـ_159.pdf
# ⬇️  Downloading (17/30): حذف-المادة-7-وتعديل-المواد-8-9-11-13-15-من-تنظيم-الهيئة-السعودية-للمحامين-لعام-1436هـ_143
# ✅ Saved: NCAR_PDFs\حذف-المادة-7-وتعديل-المواد-8-9-11-13-15-من-تنظيم-الهيئة-السعودية-للمحامين-لعام-1436هـ_143.pdf
# ⬇️  Downloading (18/30): تمديد-العمل-بوجوب-التقدم-إلى-مكتب-العمل-قبل-رفع-الدعوى-العمالية-أمام-المحاكم-العمالية-لمدة-سنة-من-تا_141
# ✅ Saved: NCAR_PDFs\تمديد-العمل-بوجوب-التقدم-إلى-مكتب-العمل-قبل-رفع-الدعوى-العمالية-أمام-المحاكم-العمالية-لمدة-سنة-من-تا_141.pdf
# ⬇️  Downloading (19/30): اعتماد-الترقيم-المستخدم-في-العنوان-الوطني-في-ترقيم-العقارات-بموجب-قواعد-تسمية-الشوارع-والميادين-وترق_126
# ✅ Saved: NCAR_PDFs\اعتماد-الترقيم-المستخدم-في-العنوان-الوطني-في-ترقيم-العقارات-بموجب-قواعد-تسمية-الشوارع-والميادين-وترق_126.pdf
# ⬇️  Downloading (20/30): تعديل-المادتين-5-10-من-تنظيم-المركز-الوطني-للأرصاد-لعام-1440هـ_127
# ✅ Saved: NCAR_PDFs\تعديل-المادتين-5-10-من-تنظيم-المركز-الوطني-للأرصاد-لعام-1440هـ_127.pdf
# ⬇️  Downloading (21/30): نظام-الإحصاء-لعام-1447هـ_م29
# ✅ Saved: NCAR_PDFs\نظام-الإحصاء-لعام-1447هـ_م29.pdf
# ⬇️  Downloading (22/30): تعديل-الفقرتين-4-و-5-من-المادة-6-من-اللائحة-التنفيذية-لنظام-مهنة-المحاسبة-والمراجعة-لعام-1442هـ_28
# ✅ Saved: NCAR_PDFs\تعديل-الفقرتين-4-و-5-من-المادة-6-من-اللائحة-التنفيذية-لنظام-مهنة-المحاسبة-والمراجعة-لعام-1442هـ_28.pdf
# ⬇️  Downloading (23/30): تعديل-المواد-1-2-4-من-تنظيم-الهيئة-السعودية-للبحر-الأحمر-لعام-1445هـ_78
# ✅ Saved: NCAR_PDFs\تعديل-المواد-1-2-4-من-تنظيم-الهيئة-السعودية-للبحر-الأحمر-لعام-1445هـ_78.pdf
# ⬇️  Downloading (24/30): تمكين-أمانة-محافظة-جدة-من-تنفيذ-مهمات-الرقابة-وحماية-الساحل-الممتد-من-مركز-السطح-بمحافظة-رابغ-شمالا-_80
# ✅ Saved: NCAR_PDFs\تمكين-أمانة-محافظة-جدة-من-تنفيذ-مهمات-الرقابة-وحماية-الساحل-الممتد-من-مركز-السطح-بمحافظة-رابغ-شمالا-_80.pdf
# ⬇️  Downloading (25/30): ضم-المركز-الوطني-لتنمية-القطاع-غير-الربحي-إلى-عضوية-اللجنة-الدائمة-لمكافحة-غسل-الأموال_83
# ✅ Saved: NCAR_PDFs\ضم-المركز-الوطني-لتنمية-القطاع-غير-الربحي-إلى-عضوية-اللجنة-الدائمة-لمكافحة-غسل-الأموال_83.pdf
# ⬇️  Downloading (26/30): تعديل-المواد-11-12-38-40-من-نظام-التوثيق-لعام-1441هـ_م21
# ✅ Saved: NCAR_PDFs\تعديل-المواد-11-12-38-40-من-نظام-التوثيق-لعام-1441هـ_م21.pdf
# ⬇️  Downloading (27/30): تعديل-المادتين-10-50-من-نظام-التحكيم-لعام-1433هـ_م21
# ✅ Saved: NCAR_PDFs\تعديل-المادتين-10-50-من-نظام-التحكيم-لعام-1433هـ_م21.pdf
# ⬇️  Downloading (28/30): تعديل-المادتين-18-26-من-نظام-المحاماة-لعام-1422هـ_م21
# ✅ Saved: NCAR_PDFs\تعديل-المادتين-18-26-من-نظام-المحاماة-لعام-1422هـ_م21.pdf
# ⬇️  Downloading (29/30): إلغاء-المادة-15-من-تنظيم-هيئة-المدن-والمناطق-الاقتصادية-الخاصة-لعام-1431هـ_أ19
# ✅ Saved: NCAR_PDFs\إلغاء-المادة-15-من-تنظيم-هيئة-المدن-والمناطق-الاقتصادية-الخاصة-لعام-1431هـ_أ19.pdf
# ⬇️  Downloading (30/30): اشتراطات-ورش-إصلاح-وسائل-النقل-لعام-1447هـ_46008629091
# ✅ Saved: NCAR_PDFs\اشتراطات-ورش-إصلاح-وسائل-النقل-لعام-1447هـ_46008629091.pdf
#
# 🎉 PDF download complete: 30/30 successful.

# %%
# ABBYY Vantage — one-cell token + skills check
import os, json, requests

# ==== CONFIG (edit these) ====
CLIENT_ID = "0JwmpC-UcmL3s7KUdlukm_-Rla2pkg"
CLIENT_SECRET = "eJWlhYAPWHsL1fWDjtFDRTNivI2vvgTTHW"
TOKEN_URL = "https://vantage-eu.abbyy.com/auth2/connect/token"
SKILLS_URL = "https://vantage-eu.abbyy.com/api/publicapi/v1/skills"
SCOPE = "openid permissions global.wildcard"
# Optional: corporate proxy (uncomment & set if needed)
# os.environ["HTTPS_PROXY"] = "http://proxy.host:port"

def get_token():
    headers = {"Content-Type": "application/x-www-form-urlencoded"}
    data = {
        "grant_type": "client_credentials",
        "client_id": CLIENT_ID,
        "client_secret": CLIENT_SECRET,
        "scope": SCOPE,
    }
    r = requests.post(TOKEN_URL, data=data, headers=headers, timeout=60)
    try:
        r.raise_for_status()
    except Exception as e:
        print("❌ Token request failed:", e)
        print("Status:", r.status_code, "| Body:", r.text[:500])
        raise
    j = r.json()
    token = j.get("access_token")
    if not token:
        raise RuntimeError(f"Token missing in response: {j}")
    os.environ["ABBYY_TOKEN"] = token
    print(f"✅ Token acquired (expires_in={j.get('expires_in')}s) and saved to os.environ['ABBYY_TOKEN']")
    return token

def call_skills(token):
    r = requests.get(
        SKILLS_URL,
        headers={"Authorization": f"Bearer {token}", "Accept": "application/json"},
        timeout=60,
    )
    ct = r.headers.get("Content-Type", "")
    print("Skills status:", r.status_code)
    if r.status_code == 403:
        print("⚠️  Forbidden (403). This client likely lacks permissions.")
        print("   In Vantage Admin → Public API Client → Manage Roles, assign at least 'Skill User'.")
        print("   Then re-run this cell to fetch a NEW token and retry.")
    if ct.startswith("application/json"):
        try:
            data = r.json()
            # print a compact list (id + name if present)
            if isinstance(data, list):
                preview = [
                    {k: v for k, v in s.items() if k.lower() in ("id", "name", "title")}
                    for s in data
                ]
                print(json.dumps(preview, indent=2)[:2000])
            else:
                print(json.dumps(data, indent=2)[:2000])
        except Exception:
            print("Received JSON content but parsing failed; raw text preview:\n", r.text[:1000])
    else:
        print("Non-JSON response preview:\n", r.text[:1000])

# ---- run both steps ----
token = get_token()
call_skills(token)
# Out:
# ✅ Token acquired (expires_in=86400s) and saved to os.environ['ABBYY_TOKEN']
# Skills status: 200
# [
#   {
#     "id": "1458486c-6a43-4323-b95b-965a0ba98849",
#     "name": "arabic"
#   }
# ]

# %%
# ABBYY Vantage Transaction Processing Workflow
import os
import json
import time
import requests
from pathlib import Path

# Configuration
SKILL_ID = "1458486c-6a43-4323-b95b-965a0ba98849"
BASE_URL = "https://vantage-eu.abbyy.com/api/publicapi/v1"
PDF_FOLDER = "NCAR_PDFs"
OUTPUT_FOLDER = "ABBYY_Processed"
POLL_INTERVAL = 30  # seconds between status checks
MAX_POLL_ATTEMPTS = 60  # maximum polling attempts (30 min total)

def create_transaction(pdf_file_path, token):
    """Create a transaction for processing a PDF file."""
    url = f"{BASE_URL}/transactions/launch"
    
    # Prepare the model data
    model_data = {
        "files": [
            {
                "index": 0,
                "imageProcessingOptions": {
                    "autoCrop": "Default",
                    "autoOrientation": "Default"
                },
                "registrationParameters": []
            }
        ],
        "registrationParameters": [],
        "skillParameters": []
    }
    
    headers = {
        "accept": "text/plain",
        "Authorization": f"Bearer {token}"
    }
    
    params = {"skillId": SKILL_ID}
    
    # Prepare multipart form data
    files = {
        'Model': (None, json.dumps(model_data), 'application/json'),
        'Files': (os.path.basename(pdf_file_path), open(pdf_file_path, 'rb'), 'application/pdf')
    }
    
    try:
        print(f"🚀 Creating transaction for: {os.path.basename(pdf_file_path)}")
        response = requests.post(url, headers=headers, params=params, files=files, timeout=60)
        
        # Close the file handle
        files['Files'][1].close()
        
        response.raise_for_status()
        
        # Parse response
        if response.headers.get('Content-Type', '').startswith('application/json'):
            result = response.json()
            transaction_id = result.get('transactionId')
            if transaction_id:
                print(f"✅ Transaction created: {transaction_id}")
                return transaction_id
            else:
                print(f"❌ No transaction ID in response: {result}")
                return None
        else:
            # Some APIs return transaction ID as plain text
            transaction_id = response.text.strip().strip('"')
            if transaction_id and len(transaction_id) > 10:  # Basic validation
                print(f"✅ Transaction created: {transaction_id}")
                return transaction_id
            else:
                print(f"❌ Invalid response: {response.text}")
                return None
            
    except requests.RequestException as e:
        print(f"❌ Error creating transaction for {os.path.basename(pdf_file_path)}: {e}")
        return None
    except Exception as e:
        print(f"❌ Unexpected error: {e}")
        return None

def check_transaction_status(transaction_id, token):
    """Check the status of a transaction."""
    url = f"{BASE_URL}/transactions/{transaction_id}"
    headers = {
        "accept": "text/plain",
        "Authorization": f"Bearer {token}"
    }
    
    try:
        response = requests.get(url, headers=headers, timeout=30)
        response.raise_for_status()
        
        if response.headers.get('Content-Type', '').startswith('application/json'):
            return response.json()
        else:
            # Try to parse as JSON anyway
            try:
                return json.loads(response.text)
            except:
                print(f"❌ Non-JSON response: {response.text[:200]}")
                return None
                
    except requests.RequestException as e:
        print(f"❌ Error checking transaction {transaction_id}: {e}")
        return None

def wait_for_transaction_completion(transaction_id, token):
    """Poll transaction status until completion."""
    print(f"⏳ Waiting for transaction {transaction_id} to complete...")
    
    for attempt in range(MAX_POLL_ATTEMPTS):
        status_data = check_transaction_status(transaction_id, token)
        
        if not status_data:
            print(f"❌ Failed to get status for transaction {transaction_id}")
            return None
            
        status = status_data.get('status', 'Unknown')
        print(f"📊 Transaction {transaction_id} status: {status} (attempt {attempt + 1})")
        
        if status == 'Processed':
            print(f"✅ Transaction {transaction_id} completed successfully!")
            return status_data
        elif status in ['Failed', 'Error', 'Cancelled']:
            print(f"❌ Transaction {transaction_id} failed with status: {status}")
            return status_data
        elif status in ['Processing', 'Queued', 'InProgress', 'Pending']:
            if attempt < MAX_POLL_ATTEMPTS - 1:
                print(f"⏳ Still processing... waiting {POLL_INTERVAL}s")
                time.sleep(POLL_INTERVAL)
            else:
                print(f"⏰ Maximum polling attempts reached for transaction {transaction_id}")
                return status_data
        else:
            print(f"❓ Unknown status '{status}' for transaction {transaction_id}")
            if attempt < MAX_POLL_ATTEMPTS - 1:
                time.sleep(POLL_INTERVAL)
    
    return status_data

def download_result_files(transaction_data, token, output_dir):
    """Download all result files from a completed transaction."""
    transaction_id = transaction_data.get('id')
    documents = transaction_data.get('documents', [])
    
    if not documents:
        print(f"⚠️  No documents found in transaction {transaction_id}")
        return []
    
    downloaded_files = []
    os.makedirs(output_dir, exist_ok=True)
    
    for doc_idx, document in enumerate(documents):
        result_files = document.get('resultFiles', [])
        
        for file_idx, result_file in enumerate(result_files):
            file_id = result_file.get('fileId')
            file_name = result_file.get('fileName', f'result_{doc_idx}_{file_idx}')
            
            if not file_id:
                print(f"⚠️  No file ID for result file: {file_name}")
                continue
                
            # Download URL
            download_url = f"{BASE_URL}/transactions/{transaction_id}/files/{file_id}/download"
            headers = {
                "accept": "application/octet-stream",
                "Authorization": f"Bearer {token}"
            }
            
            try:
                print(f"⬇️  Downloading: {file_name}")
                response = requests.get(download_url, headers=headers, stream=True, timeout=60)
                response.raise_for_status()
                
                # Save file
                output_path = os.path.join(output_dir, file_name)
                with open(output_path, 'wb') as f:
                    for chunk in response.iter_content(chunk_size=8192):
                        f.write(chunk)
                
                print(f"✅ Downloaded: {output_path}")
                downloaded_files.append(output_path)
                
            except requests.RequestException as e:
                print(f"❌ Error downloading {file_name}: {e}")
            except Exception as e:
                print(f"❌ Unexpected error downloading {file_name}: {e}")
    
    return downloaded_files

def process_all_pdfs():
    """Main function to process all PDFs in the NCAR_PDFs folder."""
    # Get token (should already be available from previous cell)
    token = os.environ.get('ABBYY_TOKEN')
    if not token:
        print("❌ No ABBYY token found. Please run the token acquisition cell first.")
        return
    
    # Check if PDF folder exists
    if not os.path.exists(PDF_FOLDER):
        print(f"❌ PDF folder '{PDF_FOLDER}' not found. Please run the NCAR scraper first.")
        return
    
    # Get all PDF files
    pdf_files = [f for f in os.listdir(PDF_FOLDER) if f.lower().endswith('.pdf')]
    
    if not pdf_files:
        print(f"❌ No PDF files found in '{PDF_FOLDER}'")
        return
    
    print(f"📁 Found {len(pdf_files)} PDF files to process")
    
    # Track all transactions
    transactions = []
    
    # Create transactions for all PDFs
    print("\n🚀 Creating transactions...")
    for pdf_file in pdf_files:
        pdf_path = os.path.join(PDF_FOLDER, pdf_file)
        transaction_id = create_transaction(pdf_path, token)
        
        if transaction_id:
            transactions.append({
                'id': transaction_id,
                'pdf_file': pdf_file,
                'status': 'Created'
            })
        
        # Small delay between requests
        time.sleep(1)
    
    if not transactions:
        print("❌ No transactions were created successfully.")
        return
    
    print(f"\n✅ Created {len(transactions)} transactions")
    
    # Wait for all transactions to complete
    print("\n⏳ Waiting for all transactions to complete...")
    completed_transactions = []
    
    for transaction in transactions:
        print(f"\n--- Processing transaction for {transaction['pdf_file']} ---")
        result = wait_for_transaction_completion(transaction['id'], token)
        
        if result and result.get('status') == 'Processed':
            completed_transactions.append(result)
            transaction['status'] = 'Completed'
        else:
            transaction['status'] = 'Failed'
    
    # Download all result files
    if completed_transactions:
        print(f"\n⬇️  Downloading results from {len(completed_transactions)} completed transactions...")
        all_downloaded_files = []
        
        for transaction_data in completed_transactions:
            downloaded = download_result_files(transaction_data, token, OUTPUT_FOLDER)
            all_downloaded_files.extend(downloaded)
        
        print(f"\n🎉 Processing complete!")
        print(f"📊 Transactions created: {len(transactions)}")
        print(f"✅ Transactions completed: {len(completed_transactions)}")
        print(f"📥 Files downloaded: {len(all_downloaded_files)}")
        print(f"📁 Output folder: {OUTPUT_FOLDER}")
        
        # Summary
        print(f"\n📋 Transaction Summary:")
        for transaction in transactions:
            status_emoji = "✅" if transaction['status'] == 'Completed' else "❌" if transaction['status'] == 'Failed' else "⏳"
            print(f"  {status_emoji} {transaction['pdf_file']}: {transaction['status']}")
        
    else:
        print("❌ No transactions completed successfully.")

# Run the complete workflow
print("🌟 Starting ABBYY Vantage processing workflow...")
process_all_pdfs()
# Out:
# 🌟 Starting ABBYY Vantage processing workflow...
# 📁 Found 30 PDF files to process
#
# 🚀 Creating transactions...
# 🚀 Creating transaction for: آلية-مشاركة-الجهات-الحكومية-في-معارض-الكتاب-الدولية-لعام-1447هـ_24939.pdf
# ✅ Transaction created: 6162a297-94b0-4ad5-b6bc-998ba7688825
# 🚀 Creating transaction for: إحلال-عبارة-وزارة-البلديات-والإسكان-محل-عبارة-وزارة-الشؤون-البلدية-والقروية-والإسكان-وإحلال-عبارة-وز_181.pdf
# ✅ Transaction created: 0fa4f3a8-7855-45c1-9e42-650bfc262b2a
# 🚀 Creating transaction for: إضافة-صلاحية-تحديد-المقابل-المالي-لعمل-المرافقين-والمرافقات-للعمالة-الوافدة-النظامية-في-المملكة-لوزي_229.pdf
# ✅ Transaction created: c1a93c9e-0806-4da0-82a6-ced7db4c226f
# 🚀 Creating transaction for: إضافة-فقرة-إلى-البند-ثالثا-من-إعادة-تنظيم-إجراءات-عملية-نشر-الأنظمة-في-الجريدة-الرسمية-لعام-1425هـ_159.pdf
# ✅ Transaction created: 245f360f-9d01-486c-9fcd-35f87fc4f8ed
# 🚀 Creating transaction for: إضافة-ممثل-لكل-من-هيئة-تنمية-البحث-والتطوير-والابتكار-وهيئة-فنون-الطهي-والهيئة-العامة-للأمن-الغذائي-_216.pdf
# ✅ Transaction created: dd8ea4df-8b16-4fd3-bce3-c2f89ad8ecbc
# 🚀 Creating transaction for: إلغاء-المادة-15-من-تنظيم-هيئة-المدن-والمناطق-الاقتصادية-الخاصة-لعام-1431هـ_أ19.pdf
# ✅ Transaction created: 0bc23e8b-e640-47b7-bf1c-6d433952744b
# 🚀 Creating transaction for: إنشاء-فرع-لجامعة-الأعمال-والتكنولوجيا-الأهلية-بمحافظة-ينبع_198.pdf
# ✅ Transaction created: 28a25203-e98d-4023-a54d-0fa8a42959f6
# 🚀 Creating transaction for: اشتراطات-ورش-إصلاح-وسائل-النقل-لعام-1447هـ_46008629091.pdf
# ✅ Transaction created: c2bcac14-7c8e-4e0f-a1ba-0ddbc14758cd
# 🚀 Creating transaction for: اعتماد-الترقيم-المستخدم-في-العنوان-الوطني-في-ترقيم-العقارات-بموجب-قواعد-تسمية-الشوارع-والميادين-وترق_126.pdf
# ✅ Transaction created: 48431e1b-b916-45f2-8048-38e5332605a4
# 🚀 Creating transaction for: الاشتراطات-البلدية-لتصريح-إشغال-رصيف-لعام-1447هـ_14700073988.pdf
# ✅ Transaction created: 62cbf446-64b7-45a2-8b74-e435acaafb4a
# 🚀 Creating transaction for: تحديد-النطاق-الجغرافي-لمحمية-مجامع-الهضب_197.pdf
# ✅ Transaction created: 27f3baba-de5c-4c78-9f80-b1c81c029e8f
# 🚀 Creating transaction for: تعديل-الفقرة-1-من-المادة-4-من-تنظيم-هيئة-المدن-والمناطق-الاقتصادية-الخاصة-لعام-1431هـ_أ76.pdf
# ✅ Transaction created: c5598777-40b1-4f9f-ba80-2cc61335d0d4
# 🚀 Creating transaction for: تعديل-الفقرتين-4-و-5-من-المادة-6-من-اللائحة-التنفيذية-لنظام-مهنة-المحاسبة-والمراجعة-لعام-1442هـ_28.pdf
# ✅ Transaction created: cf07a622-ba66-4389-bcfe-15d3cef246ec
# 🚀 Creating transaction for: تعديل-المادة-74-من-نظام-المرور-لعام-1428هـ_م50.pdf
# ✅ Transaction created: b1cea390-89f5-4e57-8642-2d59cb7bf941
# 🚀 Creating transaction for: تعديل-المادتين-10-50-من-نظام-التحكيم-لعام-1433هـ_م21.pdf
# ✅ Transaction created: df3a00fe-75c5-4d48-918d-190a9b3eb5a5
# 🚀 Creating transaction for: تعديل-المادتين-18-26-من-نظام-المحاماة-لعام-1422هـ_م21.pdf
# ✅ Transaction created: 9d9681b3-f973-440e-9f40-8b5cec994aa7
# 🚀 Creating transaction for: تعديل-المادتين-5-10-من-تنظيم-المركز-الوطني-للأرصاد-لعام-1440هـ_127.pdf
# ✅ Transaction created: aa142dd8-19ab-4963-b023-14100dd8bcf5
# 🚀 Creating transaction for: تعديل-المواد-1-2-4-من-تنظيم-الهيئة-السعودية-للبحر-الأحمر-لعام-1445هـ_78.pdf
# ✅ Transaction created: a2440d0c-8bb7-4c09-bc3c-c3166fbb6ae0
# 🚀 Creating transaction for: تعديل-المواد-11-12-38-40-من-نظام-التوثيق-لعام-1441هـ_م21.pdf
# ✅ Transaction created: a440c672-2ffa-4003-a427-3e6da177eb6e
# 🚀 Creating transaction for: تمديد-العمل-بوجوب-التقدم-إلى-مكتب-العمل-قبل-رفع-الدعوى-العمالية-أمام-المحاكم-العمالية-لمدة-سنة-من-تا_141.pdf
# ✅ Transaction created: 5852ae8e-6970-4341-b98f-96b9433816df
# 🚀 Creating transaction for: تمكين-أمانة-محافظة-جدة-من-تنفيذ-مهمات-الرقابة-وحماية-الساحل-الممتد-من-مركز-السطح-بمحافظة-رابغ-شمالا-_80.pdf
# ✅ Transaction created: c92b3e41-00c0-47d7-b5d4-fac0751bc6b3
# 🚀 Creating transaction for: تنظيم-المركز-الوطني-لسلامة-النقل-لعام-1447هـ_212.pdf
# ✅ Transaction created: fdc01da0-56da-412a-8f43-f158763dbce3
# 🚀 Creating transaction for: تولي-هيئة-التراث-تنظيم-نشاط-الحرف-والصناعات-اليدوية-وفقا-لما-يحدده-نظام-الحرف-والصناعات-اليدوية_157.pdf
# ✅ Transaction created: ea73ee0e-eaf0-4da0-974a-72917444d870
# 🚀 Creating transaction for: حذف-المادة-7-وتعديل-المواد-8-9-11-13-15-من-تنظيم-الهيئة-السعودية-للمحامين-لعام-1436هـ_143.pdf
# ✅ Transaction created: fdad0db9-35d6-4215-8c7e-a4ee68abb77a
# 🚀 Creating transaction for: ضم-المركز-الوطني-لتنمية-القطاع-غير-الربحي-إلى-عضوية-اللجنة-الدائمة-لمكافحة-غسل-الأموال_83.pdf
# ✅ Transaction created: 8ad0f931-91f3-4fc5-97c0-a3893ad0e8b2
# 🚀 Creating transaction for: قواعد-تحديد-درجات-إركاب-الموظفين-والعاملين-في-الأجهزة-العامة-من-مدنيين-وعسكريين-لعام-1447هـ_196.pdf
# ✅ Transaction created: 5b81bb0d-a8cb-480d-8b6a-fc9dbbd0268a
# 🚀 Creating transaction for: نظام-الإحصاء-لعام-1447هـ_م29.pdf
# ✅ Transaction created: 8a1ad03c-fd83-4a42-85d7-5af88109b4f9
# 🚀 Creating transaction for: نظام-الحرف-والصناعات-اليدوية-لعام-1447هـ_م49.pdf
# ✅ Transaction created: b1ae8e60-ab89-4389-a239-25f462ded643
# 🚀 Creating transaction for: نظام-نزع-ملكية-العقارات-للمصلحة-العامة-ووضع-اليد-المؤقت-على-العقارات-لعام-1447هـ_م56.pdf
# ✅ Transaction created: 50f28c96-3d1f-42a6-8940-c2aec21bc4ad
# 🚀 Creating transaction for: يجوز-لوزير-التجارة-في-الحالات-التي-يقدرها-تعيين-جميع-أعضاء-مجلس-إدارة-الغرفة-التجارية_م51.pdf
# ✅ Transaction created: b31651f3-2b7d-4149-8141-d7ce00bf661a
#
# ✅ Created 30 transactions
#
# ⏳ Waiting for all transactions to complete...
#
# --- Processing transaction for آلية-مشاركة-الجهات-الحكومية-في-معارض-الكتاب-الدولية-لعام-1447هـ_24939.pdf ---
# ⏳ Waiting for transaction 6162a297-94b0-4ad5-b6bc-998ba7688825 to complete...
# 📊 Transaction 6162a297-94b0-4ad5-b6bc-998ba7688825 status: Processed (attempt 1)
# ✅ Transaction 6162a297-94b0-4ad5-b6bc-998ba7688825 completed successfully!
#
# --- Processing transaction for إحلال-عبارة-وزارة-البلديات-والإسكان-محل-عبارة-وزارة-الشؤون-البلدية-والقروية-والإسكان-وإحلال-عبارة-وز_181.pdf ---
# ⏳ Waiting for transaction 0fa4f3a8-7855-45c1-9e42-650bfc262b2a to complete...
# 📊 Transaction 0fa4f3a8-7855-45c1-9e42-650bfc262b2a status: Processed (attempt 1)
# ✅ Transaction 0fa4f3a8-7855-45c1-9e42-650bfc262b2a completed successfully!
#
# --- Processing transaction for إضافة-صلاحية-تحديد-المقابل-المالي-لعمل-المرافقين-والمرافقات-للعمالة-الوافدة-النظامية-في-المملكة-لوزي_229.pdf ---
# ⏳ Waiting for transaction c1a93c9e-0806-4da0-82a6-ced7db4c226f to complete...
# 📊 Transaction c1a93c9e-0806-4da0-82a6-ced7db4c226f status: Processed (attempt 1)
# ✅ Transaction c1a93c9e-0806-4da0-82a6-ced7db4c226f completed successfully!
#
# --- Processing transaction for إضافة-فقرة-إلى-البند-ثالثا-من-إعادة-تنظيم-إجراءات-عملية-نشر-الأنظمة-في-الجريدة-الرسمية-لعام-1425هـ_159.pdf ---
# ⏳ Waiting for transaction 245f360f-9d01-486c-9fcd-35f87fc4f8ed to complete...
# 📊 Transaction 245f360f-9d01-486c-9fcd-35f87fc4f8ed status: Processed (attempt 1)
# ✅ Transaction 245f360f-9d01-486c-9fcd-35f87fc4f8ed completed successfully!
#
# --- Processing transaction for إضافة-ممثل-لكل-من-هيئة-تنمية-البحث-والتطوير-والابتكار-وهيئة-فنون-الطهي-والهيئة-العامة-للأمن-الغذائي-_216.pdf ---
# ⏳ Waiting for transaction dd8ea4df-8b16-4fd3-bce3-c2f89ad8ecbc to complete...
# 📊 Transaction dd8ea4df-8b16-4fd3-bce3-c2f89ad8ecbc status: Processed (attempt 1)
# ✅ Transaction dd8ea4df-8b16-4fd3-bce3-c2f89ad8ecbc completed successfully!
#
# --- Processing transaction for إلغاء-المادة-15-من-تنظيم-هيئة-المدن-والمناطق-الاقتصادية-الخاصة-لعام-1431هـ_أ19.pdf ---
# ⏳ Waiting for transaction 0bc23e8b-e640-47b7-bf1c-6d433952744b to complete...
# 📊 Transaction 0bc23e8b-e640-47b7-bf1c-6d433952744b status: Processed (attempt 1)
# ✅ Transaction 0bc23e8b-e640-47b7-bf1c-6d433952744b completed successfully!
#
# --- Processing transaction for إنشاء-فرع-لجامعة-الأعمال-والتكنولوجيا-الأهلية-بمحافظة-ينبع_198.pdf ---
# ⏳ Waiting for transaction 28a25203-e98d-4023-a54d-0fa8a42959f6 to complete...
# 📊 Transaction 28a25203-e98d-4023-a54d-0fa8a42959f6 status: Processed (attempt 1)
# ✅ Transaction 28a25203-e98d-4023-a54d-0fa8a42959f6 completed successfully!
#
# --- Processing transaction for اشتراطات-ورش-إصلاح-وسائل-النقل-لعام-1447هـ_46008629091.pdf ---
# ⏳ Waiting for transaction c2bcac14-7c8e-4e0f-a1ba-0ddbc14758cd to complete...
# 📊 Transaction c2bcac14-7c8e-4e0f-a1ba-0ddbc14758cd status: Processed (attempt 1)
# ✅ Transaction c2bcac14-7c8e-4e0f-a1ba-0ddbc14758cd completed successfully!
#
# --- Processing transaction for اعتماد-الترقيم-المستخدم-في-العنوان-الوطني-في-ترقيم-العقارات-بموجب-قواعد-تسمية-الشوارع-والميادين-وترق_126.pdf ---
# ⏳ Waiting for transaction 48431e1b-b916-45f2-8048-38e5332605a4 to complete...
# 📊 Transaction 48431e1b-b916-45f2-8048-38e5332605a4 status: Processed (attempt 1)
# ✅ Transaction 48431e1b-b916-45f2-8048-38e5332605a4 completed successfully!
#
# --- Processing transaction for الاشتراطات-البلدية-لتصريح-إشغال-رصيف-لعام-1447هـ_14700073988.pdf ---
# ⏳ Waiting for transaction 62cbf446-64b7-45a2-8b74-e435acaafb4a to complete...
# 📊 Transaction 62cbf446-64b7-45a2-8b74-e435acaafb4a status: Processed (attempt 1)
# ✅ Transaction 62cbf446-64b7-45a2-8b74-e435acaafb4a completed successfully!
#
# --- Processing transaction for تحديد-النطاق-الجغرافي-لمحمية-مجامع-الهضب_197.pdf ---
# ⏳ Waiting for transaction 27f3baba-de5c-4c78-9f80-b1c81c029e8f to complete...
# 📊 Transaction 27f3baba-de5c-4c78-9f80-b1c81c029e8f status: Processed (attempt 1)
# ✅ Transaction 27f3baba-de5c-4c78-9f80-b1c81c029e8f completed successfully!
#
# --- Processing transaction for تعديل-الفقرة-1-من-المادة-4-من-تنظيم-هيئة-المدن-والمناطق-الاقتصادية-الخاصة-لعام-1431هـ_أ76.pdf ---
# ⏳ Waiting for transaction c5598777-40b1-4f9f-ba80-2cc61335d0d4 to complete...
# 📊 Transaction c5598777-40b1-4f9f-ba80-2cc61335d0d4 status: Processed (attempt 1)
# ✅ Transaction c5598777-40b1-4f9f-ba80-2cc61335d0d4 completed successfully!
#
# --- Processing transaction for تعديل-الفقرتين-4-و-5-من-المادة-6-من-اللائحة-التنفيذية-لنظام-مهنة-المحاسبة-والمراجعة-لعام-1442هـ_28.pdf ---
# ⏳ Waiting for transaction cf07a622-ba66-4389-bcfe-15d3cef246ec to complete...
# 📊 Transaction cf07a622-ba66-4389-bcfe-15d3cef246ec status: Processed (attempt 1)
# ✅ Transaction cf07a622-ba66-4389-bcfe-15d3cef246ec completed successfully!
#
# --- Processing transaction for تعديل-المادة-74-من-نظام-المرور-لعام-1428هـ_م50.pdf ---
# ⏳ Waiting for transaction b1cea390-89f5-4e57-8642-2d59cb7bf941 to complete...
# 📊 Transaction b1cea390-89f5-4e57-8642-2d59cb7bf941 status: Processed (attempt 1)
# ✅ Transaction b1cea390-89f5-4e57-8642-2d59cb7bf941 completed successfully!
#
# --- Processing transaction for تعديل-المادتين-10-50-من-نظام-التحكيم-لعام-1433هـ_م21.pdf ---
# ⏳ Waiting for transaction df3a00fe-75c5-4d48-918d-190a9b3eb5a5 to complete...
# 📊 Transaction df3a00fe-75c5-4d48-918d-190a9b3eb5a5 status: Processed (attempt 1)
# ✅ Transaction df3a00fe-75c5-4d48-918d-190a9b3eb5a5 completed successfully!
#
# --- Processing transaction for تعديل-المادتين-18-26-من-نظام-المحاماة-لعام-1422هـ_م21.pdf ---
# ⏳ Waiting for transaction 9d9681b3-f973-440e-9f40-8b5cec994aa7 to complete...
# 📊 Transaction 9d9681b3-f973-440e-9f40-8b5cec994aa7 status: Processed (attempt 1)
# ✅ Transaction 9d9681b3-f973-440e-9f40-8b5cec994aa7 completed successfully!
#
# --- Processing transaction for تعديل-المادتين-5-10-من-تنظيم-المركز-الوطني-للأرصاد-لعام-1440هـ_127.pdf ---
# ⏳ Waiting for transaction aa142dd8-19ab-4963-b023-14100dd8bcf5 to complete...
# 📊 Transaction aa142dd8-19ab-4963-b023-14100dd8bcf5 status: Processed (attempt 1)
# ✅ Transaction aa142dd8-19ab-4963-b023-14100dd8bcf5 completed successfully!
#
# --- Processing transaction for تعديل-المواد-1-2-4-من-تنظيم-الهيئة-السعودية-للبحر-الأحمر-لعام-1445هـ_78.pdf ---
# ⏳ Waiting for transaction a2440d0c-8bb7-4c09-bc3c-c3166fbb6ae0 to complete...
# 📊 Transaction a2440d0c-8bb7-4c09-bc3c-c3166fbb6ae0 status: Processed (attempt 1)
# ✅ Transaction a2440d0c-8bb7-4c09-bc3c-c3166fbb6ae0 completed successfully!
#
# --- Processing transaction for تعديل-المواد-11-12-38-40-من-نظام-التوثيق-لعام-1441هـ_م21.pdf ---
# ⏳ Waiting for transaction a440c672-2ffa-4003-a427-3e6da177eb6e to complete...
# 📊 Transaction a440c672-2ffa-4003-a427-3e6da177eb6e status: Processed (attempt 1)
# ✅ Transaction a440c672-2ffa-4003-a427-3e6da177eb6e completed successfully!
#
# --- Processing transaction for تمديد-العمل-بوجوب-التقدم-إلى-مكتب-العمل-قبل-رفع-الدعوى-العمالية-أمام-المحاكم-العمالية-لمدة-سنة-من-تا_141.pdf ---
# ⏳ Waiting for transaction 5852ae8e-6970-4341-b98f-96b9433816df to complete...
# 📊 Transaction 5852ae8e-6970-4341-b98f-96b9433816df status: Processed (attempt 1)
# ✅ Transaction 5852ae8e-6970-4341-b98f-96b9433816df completed successfully!
#
# --- Processing transaction for تمكين-أمانة-محافظة-جدة-من-تنفيذ-مهمات-الرقابة-وحماية-الساحل-الممتد-من-مركز-السطح-بمحافظة-رابغ-شمالا-_80.pdf ---
# ⏳ Waiting for transaction c92b3e41-00c0-47d7-b5d4-fac0751bc6b3 to complete...
# 📊 Transaction c92b3e41-00c0-47d7-b5d4-fac0751bc6b3 status: Processed (attempt 1)
# ✅ Transaction c92b3e41-00c0-47d7-b5d4-fac0751bc6b3 completed successfully!
#
# --- Processing transaction for تنظيم-المركز-الوطني-لسلامة-النقل-لعام-1447هـ_212.pdf ---
# ⏳ Waiting for transaction fdc01da0-56da-412a-8f43-f158763dbce3 to complete...
# 📊 Transaction fdc01da0-56da-412a-8f43-f158763dbce3 status: Processed (attempt 1)
# ✅ Transaction fdc01da0-56da-412a-8f43-f158763dbce3 completed successfully!
#
# --- Processing transaction for تولي-هيئة-التراث-تنظيم-نشاط-الحرف-والصناعات-اليدوية-وفقا-لما-يحدده-نظام-الحرف-والصناعات-اليدوية_157.pdf ---
# ⏳ Waiting for transaction ea73ee0e-eaf0-4da0-974a-72917444d870 to complete...
# 📊 Transaction ea73ee0e-eaf0-4da0-974a-72917444d870 status: Processed (attempt 1)
# ✅ Transaction ea73ee0e-eaf0-4da0-974a-72917444d870 completed successfully!
#
# --- Processing transaction for حذف-المادة-7-وتعديل-المواد-8-9-11-13-15-من-تنظيم-الهيئة-السعودية-للمحامين-لعام-1436هـ_143.pdf ---
# ⏳ Waiting for transaction fdad0db9-35d6-4215-8c7e-a4ee68abb77a to complete...
# 📊 Transaction fdad0db9-35d6-4215-8c7e-a4ee68abb77a status: Processed (attempt 1)
# ✅ Transaction fdad0db9-35d6-4215-8c7e-a4ee68abb77a completed successfully!
#
# --- Processing transaction for ضم-المركز-الوطني-لتنمية-القطاع-غير-الربحي-إلى-عضوية-اللجنة-الدائمة-لمكافحة-غسل-الأموال_83.pdf ---
# ⏳ Waiting for transaction 8ad0f931-91f3-4fc5-97c0-a3893ad0e8b2 to complete...
# 📊 Transaction 8ad0f931-91f3-4fc5-97c0-a3893ad0e8b2 status: Processed (attempt 1)
# ✅ Transaction 8ad0f931-91f3-4fc5-97c0-a3893ad0e8b2 completed successfully!
#
# --- Processing transaction for قواعد-تحديد-درجات-إركاب-الموظفين-والعاملين-في-الأجهزة-العامة-من-مدنيين-وعسكريين-لعام-1447هـ_196.pdf ---
# ⏳ Waiting for transaction 5b81bb0d-a8cb-480d-8b6a-fc9dbbd0268a to complete...
# 📊 Transaction 5b81bb0d-a8cb-480d-8b6a-fc9dbbd0268a status: Processed (attempt 1)
# ✅ Transaction 5b81bb0d-a8cb-480d-8b6a-fc9dbbd0268a completed successfully!
#
# --- Processing transaction for نظام-الإحصاء-لعام-1447هـ_م29.pdf ---
# ⏳ Waiting for transaction 8a1ad03c-fd83-4a42-85d7-5af88109b4f9 to complete...
# 📊 Transaction 8a1ad03c-fd83-4a42-85d7-5af88109b4f9 status: Processed (attempt 1)
# ✅ Transaction 8a1ad03c-fd83-4a42-85d7-5af88109b4f9 completed successfully!
#
# --- Processing transaction for نظام-الحرف-والصناعات-اليدوية-لعام-1447هـ_م49.pdf ---
# ⏳ Waiting for transaction b1ae8e60-ab89-4389-a239-25f462ded643 to complete...
# 📊 Transaction b1ae8e60-ab89-4389-a239-25f462ded643 status: Processed (attempt 1)
# ✅ Transaction b1ae8e60-ab89-4389-a239-25f462ded643 completed successfully!
#
# --- Processing transaction for نظام-نزع-ملكية-العقارات-للمصلحة-العامة-ووضع-اليد-المؤقت-على-العقارات-لعام-1447هـ_م56.pdf ---
# ⏳ Waiting for transaction 50f28c96-3d1f-42a6-8940-c2aec21bc4ad to complete...
# 📊 Transaction 50f28c96-3d1f-42a6-8940-c2aec21bc4ad status: Processed (attempt 1)
# ✅ Transaction 50f28c96-3d1f-42a6-8940-c2aec21bc4ad completed successfully!
#
# --- Processing transaction for يجوز-لوزير-التجارة-في-الحالات-التي-يقدرها-تعيين-جميع-أعضاء-مجلس-إدارة-الغرفة-التجارية_م51.pdf ---
# ⏳ Waiting for transaction b31651f3-2b7d-4149-8141-d7ce00bf661a to complete...
# 📊 Transaction b31651f3-2b7d-4149-8141-d7ce00bf661a status: Processed (attempt 1)
# ✅ Transaction b31651f3-2b7d-4149-8141-d7ce00bf661a completed successfully!
#
# ⬇️  Downloading results from 30 completed transactions...
# ⬇️  Downloading: آلية-مشاركة-الجهات-الحكومية-في-معارض-الكتاب-الدولية-لعام-1447هـ_24939.docx
# ✅ Downloaded: ABBYY_Processed\آلية-مشاركة-الجهات-الحكومية-في-معارض-الكتاب-الدولية-لعام-1447هـ_24939.docx
# ⬇️  Downloading: إحلال-عبارة-وزارة-البلديات-والإسكان-محل-عبارة-وزارة-الشؤون-البلدية-والقروية-والإسكان-وإحلال-عبارة-وز_181.docx
# ✅ Downloaded: ABBYY_Processed\إحلال-عبارة-وزارة-البلديات-والإسكان-محل-عبارة-وزارة-الشؤون-البلدية-والقروية-والإسكان-وإحلال-عبارة-وز_181.docx
# ⬇️  Downloading: إضافة-صلاحية-تحديد-المقابل-المالي-لعمل-المرافقين-والمرافقات-للعمالة-الوافدة-النظامية-في-المملكة-لوزي_229.docx
# ✅ Downloaded: ABBYY_Processed\إضافة-صلاحية-تحديد-المقابل-المالي-لعمل-المرافقين-والمرافقات-للعمالة-الوافدة-النظامية-في-المملكة-لوزي_229.docx
# ⬇️  Downloading: إضافة-فقرة-إلى-البند-ثالثا-من-إعادة-تنظيم-إجراءات-عملية-نشر-الأنظمة-في-الجريدة-الرسمية-لعام-1425هـ_159.docx
# ✅ Downloaded: ABBYY_Processed\إضافة-فقرة-إلى-البند-ثالثا-من-إعادة-تنظيم-إجراءات-عملية-نشر-الأنظمة-في-الجريدة-الرسمية-لعام-1425هـ_159.docx
# ⬇️  Downloading: إضافة-ممثل-لكل-من-هيئة-تنمية-البحث-والتطوير-والابتكار-وهيئة-فنون-الطهي-والهيئة-العامة-للأمن-الغذائي-_216.docx
# ✅ Downloaded: ABBYY_Processed\إضافة-ممثل-لكل-من-هيئة-تنمية-البحث-والتطوير-والابتكار-وهيئة-فنون-الطهي-والهيئة-العامة-للأمن-الغذائي-_216.docx
# ⬇️  Downloading: إلغاء-المادة-15-من-تنظيم-هيئة-المدن-والمناطق-الاقتصادية-الخاصة-لعام-1431هـ_أ19.docx
# ✅ Downloaded: ABBYY_Processed\إلغاء-المادة-15-من-تنظيم-هيئة-المدن-والمناطق-الاقتصادية-الخاصة-لعام-1431هـ_أ19.docx
# ⬇️  Downloading: إنشاء-فرع-لجامعة-الأعمال-والتكنولوجيا-الأهلية-بمحافظة-ينبع_198.docx
# ✅ Downloaded: ABBYY_Processed\إنشاء-فرع-لجامعة-الأعمال-والتكنولوجيا-الأهلية-بمحافظة-ينبع_198.docx
# ⬇️  Downloading: اشتراطات-ورش-إصلاح-وسائل-النقل-لعام-1447هـ_46008629091.docx
# ✅ Downloaded: ABBYY_Processed\اشتراطات-ورش-إصلاح-وسائل-النقل-لعام-1447هـ_46008629091.docx
# ⬇️  Downloading: اعتماد-الترقيم-المستخدم-في-العنوان-الوطني-في-ترقيم-العقارات-بموجب-قواعد-تسمية-الشوارع-والميادين-وترق_126.docx
# ✅ Downloaded: ABBYY_Processed\اعتماد-الترقيم-المستخدم-في-العنوان-الوطني-في-ترقيم-العقارات-بموجب-قواعد-تسمية-الشوارع-والميادين-وترق_126.docx
# ⬇️  Downloading: الاشتراطات-البلدية-لتصريح-إشغال-رصيف-لعام-1447هـ_14700073988.docx
# ✅ Downloaded: ABBYY_Processed\الاشتراطات-البلدية-لتصريح-إشغال-رصيف-لعام-1447هـ_14700073988.docx
# ⬇️  Downloading: تحديد-النطاق-الجغرافي-لمحمية-مجامع-الهضب_197.docx
# ✅ Downloaded: ABBYY_Processed\تحديد-النطاق-الجغرافي-لمحمية-مجامع-الهضب_197.docx
# ⬇️  Downloading: تعديل-الفقرة-1-من-المادة-4-من-تنظيم-هيئة-المدن-والمناطق-الاقتصادية-الخاصة-لعام-1431هـ_أ76.docx
# ✅ Downloaded: ABBYY_Processed\تعديل-الفقرة-1-من-المادة-4-من-تنظيم-هيئة-المدن-والمناطق-الاقتصادية-الخاصة-لعام-1431هـ_أ76.docx
# ⬇️  Downloading: تعديل-الفقرتين-4-و-5-من-المادة-6-من-اللائحة-التنفيذية-لنظام-مهنة-المحاسبة-والمراجعة-لعام-1442هـ_28.docx
# ✅ Downloaded: ABBYY_Processed\تعديل-الفقرتين-4-و-5-من-المادة-6-من-اللائحة-التنفيذية-لنظام-مهنة-المحاسبة-والمراجعة-لعام-1442هـ_28.docx
# ⬇️  Downloading: تعديل-المادة-74-من-نظام-المرور-لعام-1428هـ_م50.docx
# ✅ Downloaded: ABBYY_Processed\تعديل-المادة-74-من-نظام-المرور-لعام-1428هـ_م50.docx
# ⬇️  Downloading: تعديل-المادتين-10-50-من-نظام-التحكيم-لعام-1433هـ_م21.docx
# ✅ Downloaded: ABBYY_Processed\تعديل-المادتين-10-50-من-نظام-التحكيم-لعام-1433هـ_م21.docx
# ⬇️  Downloading: تعديل-المادتين-18-26-من-نظام-المحاماة-لعام-1422هـ_م21.docx
# ✅ Downloaded: ABBYY_Processed\تعديل-المادتين-18-26-من-نظام-المحاماة-لعام-1422هـ_م21.docx
# ⬇️  Downloading: تعديل-المادتين-5-10-من-تنظيم-المركز-الوطني-للأرصاد-لعام-1440هـ_127.docx
# ✅ Downloaded: ABBYY_Processed\تعديل-المادتين-5-10-من-تنظيم-المركز-الوطني-للأرصاد-لعام-1440هـ_127.docx
# ⬇️  Downloading: تعديل-المواد-1-2-4-من-تنظيم-الهيئة-السعودية-للبحر-الأحمر-لعام-1445هـ_78.docx
# ✅ Downloaded: ABBYY_Processed\تعديل-المواد-1-2-4-من-تنظيم-الهيئة-السعودية-للبحر-الأحمر-لعام-1445هـ_78.docx
# ⬇️  Downloading: تعديل-المواد-11-12-38-40-من-نظام-التوثيق-لعام-1441هـ_م21.docx
# ✅ Downloaded: ABBYY_Processed\تعديل-المواد-11-12-38-40-من-نظام-التوثيق-لعام-1441هـ_م21.docx
# ⬇️  Downloading: تمديد-العمل-بوجوب-التقدم-إلى-مكتب-العمل-قبل-رفع-الدعوى-العمالية-أمام-المحاكم-العمالية-لمدة-سنة-من-تا_141.docx
# ✅ Downloaded: ABBYY_Processed\تمديد-العمل-بوجوب-التقدم-إلى-مكتب-العمل-قبل-رفع-الدعوى-العمالية-أمام-المحاكم-العمالية-لمدة-سنة-من-تا_141.docx
# ⬇️  Downloading: تمكين-أمانة-محافظة-جدة-من-تنفيذ-مهمات-الرقابة-وحماية-الساحل-الممتد-من-مركز-السطح-بمحافظة-رابغ-شمالا-_80.docx
# ✅ Downloaded: ABBYY_Processed\تمكين-أمانة-محافظة-جدة-من-تنفيذ-مهمات-الرقابة-وحماية-الساحل-الممتد-من-مركز-السطح-بمحافظة-رابغ-شمالا-_80.docx
# ⬇️  Downloading: تنظيم-المركز-الوطني-لسلامة-النقل-لعام-1447هـ_212.docx
# ✅ Downloaded: ABBYY_Processed\تنظيم-المركز-الوطني-لسلامة-النقل-لعام-1447هـ_212.docx
# ⬇️  Downloading: تولي-هيئة-التراث-تنظيم-نشاط-الحرف-والصناعات-اليدوية-وفقا-لما-يحدده-نظام-الحرف-والصناعات-اليدوية_157.docx
# ✅ Downloaded: ABBYY_Processed\تولي-هيئة-التراث-تنظيم-نشاط-الحرف-والصناعات-اليدوية-وفقا-لما-يحدده-نظام-الحرف-والصناعات-اليدوية_157.docx
# ⬇️  Downloading: حذف-المادة-7-وتعديل-المواد-8-9-11-13-15-من-تنظيم-الهيئة-السعودية-للمحامين-لعام-1436هـ_143.docx
# ✅ Downloaded: ABBYY_Processed\حذف-المادة-7-وتعديل-المواد-8-9-11-13-15-من-تنظيم-الهيئة-السعودية-للمحامين-لعام-1436هـ_143.docx
# ⬇️  Downloading: ضم-المركز-الوطني-لتنمية-القطاع-غير-الربحي-إلى-عضوية-اللجنة-الدائمة-لمكافحة-غسل-الأموال_83.docx
# ✅ Downloaded: ABBYY_Processed\ضم-المركز-الوطني-لتنمية-القطاع-غير-الربحي-إلى-عضوية-اللجنة-الدائمة-لمكافحة-غسل-الأموال_83.docx
# ⬇️  Downloading: قواعد-تحديد-درجات-إركاب-الموظفين-والعاملين-في-الأجهزة-العامة-من-مدنيين-وعسكريين-لعام-1447هـ_196.docx
# ✅ Downloaded: ABBYY_Processed\قواعد-تحديد-درجات-إركاب-الموظفين-والعاملين-في-الأجهزة-العامة-من-مدنيين-وعسكريين-لعام-1447هـ_196.docx
# ⬇️  Downloading: نظام-الإحصاء-لعام-1447هـ_م29.docx
# ✅ Downloaded: ABBYY_Processed\نظام-الإحصاء-لعام-1447هـ_م29.docx
# ⬇️  Downloading: نظام-الحرف-والصناعات-اليدوية-لعام-1447هـ_م49.docx
# ✅ Downloaded: ABBYY_Processed\نظام-الحرف-والصناعات-اليدوية-لعام-1447هـ_م49.docx
# ⬇️  Downloading: نظام-نزع-ملكية-العقارات-للمصلحة-العامة-ووضع-اليد-المؤقت-على-العقارات-لعام-1447هـ_م56.docx
# ✅ Downloaded: ABBYY_Processed\نظام-نزع-ملكية-العقارات-للمصلحة-العامة-ووضع-اليد-المؤقت-على-العقارات-لعام-1447هـ_م56.docx
# ⬇️  Downloading: يجوز-لوزير-التجارة-في-الحالات-التي-يقدرها-تعيين-جميع-أعضاء-مجلس-إدارة-الغرفة-التجارية_م51.docx
# ✅ Downloaded: ABBYY_Processed\يجوز-لوزير-التجارة-في-الحالات-التي-يقدرها-تعيين-جميع-أعضاء-مجلس-إدارة-الغرفة-التجارية_م51.docx
#
# 🎉 Processing complete!
# 📊 Transactions created: 30
# ✅ Transactions completed: 30
# 📥 Files downloaded: 30
# 📁 Output folder: ABBYY_Processed
#
# 📋 Transaction Summary:
#   ✅ آلية-مشاركة-الجهات-الحكومية-في-معارض-الكتاب-الدولية-لعام-1447هـ_24939.pdf: Completed
#   ✅ إحلال-عبارة-وزارة-البلديات-والإسكان-محل-عبارة-وزارة-الشؤون-البلدية-والقروية-والإسكان-وإحلال-عبارة-وز_181.pdf: Completed
#   ✅ إضافة-صلاحية-تحديد-المقابل-المالي-لعمل-المرافقين-والمرافقات-للعمالة-الوافدة-النظامية-في-المملكة-لوزي_229.pdf: Completed
#   ✅ إضافة-فقرة-إلى-البند-ثالثا-من-إعادة-تنظيم-إجراءات-عملية-نشر-الأنظمة-في-الجريدة-الرسمية-لعام-1425هـ_159.pdf: Completed
#   ✅ إضافة-ممثل-لكل-من-هيئة-تنمية-البحث-والتطوير-والابتكار-وهيئة-فنون-الطهي-والهيئة-العامة-للأمن-الغذائي-_216.pdf: Completed
#   ✅ إلغاء-المادة-15-من-تنظيم-هيئة-المدن-والمناطق-الاقتصادية-الخاصة-لعام-1431هـ_أ19.pdf: Completed
#   ✅ إنشاء-فرع-لجامعة-الأعمال-والتكنولوجيا-الأهلية-بمحافظة-ينبع_198.pdf: Completed
#   ✅ اشتراطات-ورش-إصلاح-وسائل-النقل-لعام-1447هـ_46008629091.pdf: Completed
#   ✅ اعتماد-الترقيم-المستخدم-في-العنوان-الوطني-في-ترقيم-العقارات-بموجب-قواعد-تسمية-الشوارع-والميادين-وترق_126.pdf: Completed
#   ✅ الاشتراطات-البلدية-لتصريح-إشغال-رصيف-لعام-1447هـ_14700073988.pdf: Completed
#   ✅ تحديد-النطاق-الجغرافي-لمحمية-مجامع-الهضب_197.pdf: Completed
#   ✅ تعديل-الفقرة-1-من-المادة-4-من-تنظيم-هيئة-المدن-والمناطق-الاقتصادية-الخاصة-لعام-1431هـ_أ76.pdf: Completed
#   ✅ تعديل-الفقرتين-4-و-5-من-المادة-6-من-اللائحة-التنفيذية-لنظام-مهنة-المحاسبة-والمراجعة-لعام-1442هـ_28.pdf: Completed
#   ✅ تعديل-المادة-74-من-نظام-المرور-لعام-1428هـ_م50.pdf: Completed
#   ✅ تعديل-المادتين-10-50-من-نظام-التحكيم-لعام-1433هـ_م21.pdf: Completed
#   ✅ تعديل-المادتين-18-26-من-نظام-المحاماة-لعام-1422هـ_م21.pdf: Completed
#   ✅ تعديل-المادتين-5-10-من-تنظيم-المركز-الوطني-للأرصاد-لعام-1440هـ_127.pdf: Completed
#   ✅ تعديل-المواد-1-2-4-من-تنظيم-الهيئة-السعودية-للبحر-الأحمر-لعام-1445هـ_78.pdf: Completed
#   ✅ تعديل-المواد-11-12-38-40-من-نظام-التوثيق-لعام-1441هـ_م21.pdf: Completed
#   ✅ تمديد-العمل-بوجوب-التقدم-إلى-مكتب-العمل-قبل-رفع-الدعوى-العمالية-أمام-المحاكم-العمالية-لمدة-سنة-من-تا_141.pdf: Completed
#   ✅ تمكين-أمانة-محافظة-جدة-من-تنفيذ-مهمات-الرقابة-وحماية-الساحل-الممتد-من-مركز-السطح-بمحافظة-رابغ-شمالا-_80.pdf: Completed
#   ✅ تنظيم-المركز-الوطني-لسلامة-النقل-لعام-1447هـ_212.pdf: Completed
#   ✅ تولي-هيئة-التراث-تنظيم-نشاط-الحرف-والصناعات-اليدوية-وفقا-لما-يحدده-نظام-الحرف-والصناعات-اليدوية_157.pdf: Completed
#   ✅ حذف-المادة-7-وتعديل-المواد-8-9-11-13-15-من-تنظيم-الهيئة-السعودية-للمحامين-لعام-1436هـ_143.pdf: Completed
#   ✅ ضم-المركز-الوطني-لتنمية-القطاع-غير-الربحي-إلى-عضوية-اللجنة-الدائمة-لمكافحة-غسل-الأموال_83.pdf: Completed
#   ✅ قواعد-تحديد-درجات-إركاب-الموظفين-والعاملين-في-الأجهزة-العامة-من-مدنيين-وعسكريين-لعام-1447هـ_196.pdf: Completed
#   ✅ نظام-الإحصاء-لعام-1447هـ_م29.pdf: Completed
#   ✅ نظام-الحرف-والصناعات-اليدوية-لعام-1447هـ_م49.pdf: Completed
#   ✅ نظام-نزع-ملكية-العقارات-للمصلحة-العامة-ووضع-اليد-المؤقت-على-العقارات-لعام-1447هـ_م56.pdf: Completed
#   ✅ يجوز-لوزير-التجارة-في-الحالات-التي-يقدرها-تعيين-جميع-أعضاء-مجلس-إدارة-الغرفة-التجارية_م51.pdf: Completed
