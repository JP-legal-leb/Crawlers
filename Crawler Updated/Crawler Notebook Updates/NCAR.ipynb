# %%
import os
import re
import time
import json
import requests
from datetime import datetime

print("Starting document metadata scraping...")

# --- Configuration ---
BASE_API_URL = "https://ncar.gov.sa/api/index.php/api/documents/document-search"
BASE_PDF_URL_PREFIX = "https://ncar.gov.sa/api/index.php/resource/"
BASE_PDF_URL_SUFFIX = "/Documents/OriginalAttachPath"
PDF_OUTPUT_DIR = "NCAR_PDFs"

ITEMS_PER_PAGE = 10
SORT_BY = "approveDate"
SORT_ORDER = "DESC"
START_PAGE = 1 # MODIFY START_PAGE AND END_PAGE, PAGE 1 IS MOST RECENT
END_PAGE = 3 # MODIFY START_PAGE AND END_PAGE, PAGE 1 IS MOST RECENT
REQUEST_DELAY = 0.5  # polite delay

HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36",
    "Referer": "https://ncar.gov.sa/rules-regulations"
}

BASE_PAYLOAD = {
    "approveTool_id": None,
    "documentCategory_id": None,
    "name": None,
    "ApproveDate": None,
    "PublishingStatus": None,
    "alphabeticalCategory_id": None,
    "alphabeticalSubCategory_id": [],
    "alphabeticalTopic_id": None,
    "approveDate_from": None,
    "approveDate_to": None,
    "generalCategory_id": [],
    "governmentalAgency_childId": [],
    "governmentalAgency_id": None,
    "identical": 1,
    "is_printed": None,
    "is_translated": None,
    "is_valid": None,
    "number": None,
    "omAlQourah_date": None,
    "omAlQourah_version": None,
    "particularCategory_id": [],
    "releaseOrgId": None
}


# --- Helpers ---
def sanitize_filename(name: str, max_length: int = 100) -> str:
    """Clean a string for safe filename use."""
    try:
        name = name.encode('latin1').decode('unicode_escape')
    except (UnicodeEncodeError, UnicodeDecodeError):
        pass
    s = re.sub(r"[^\w\s-]", "", name).strip()
    s = re.sub(r"[\s]+", "-", s)
    return s[:max_length] or "untitled"


def fetch_page(page_num: int, payload: dict) -> dict | None:
    """Fetch a single page of documents."""
    url = f"{BASE_API_URL}/{page_num}/{ITEMS_PER_PAGE}/{SORT_BY}/{SORT_ORDER}"
    print(f"🔎 Requesting page {page_num} ...")
    try:
        response = requests.post(url, headers=HEADERS, json=payload, timeout=15)
        response.raise_for_status()
        return response.json()
    except requests.RequestException as e:
        print(f"❌ Error fetching page {page_num}: {e}")
        return None


def save_json(data: list, start: int, end: int) -> str:
    """Save scraped data to JSON with page range + formatted date in filename."""
    os.makedirs("output", exist_ok=True)
    today = datetime.now()
    today_str = f"{today.day:02}.{today.month:02}.{today.year}"  # e.g., 09.12.2024
    filename = f"output/ncar_crawl_page{start}-{end}_({today_str}).json"
    with open(filename, "w", encoding="utf-8") as f:
        json.dump(data, f, ensure_ascii=False, indent=2)
    return filename


def download_pdf(doc: dict, index: int, total: int) -> bool:
    """Download a single PDF if available."""
    encrypted_id = doc.get("id")
    if not encrypted_id:
        print(f"⚠️  Skipping {index+1}/{total}: missing ID")
        return False

    pdf_url = f"{BASE_PDF_URL_PREFIX}{encrypted_id}{BASE_PDF_URL_SUFFIX}"
    title = sanitize_filename(doc.get("title_en", f"document_{index+1}"))
    number = sanitize_filename(doc.get("number", "")) if doc.get("number") else ""
    filename_base = f"{title}_{number}" if number else title

    os.makedirs(PDF_OUTPUT_DIR, exist_ok=True)
    pdf_path = os.path.join(PDF_OUTPUT_DIR, f"{filename_base}.pdf")

    print(f"⬇️  Downloading ({index+1}/{total}): {filename_base}")

    try:
        with requests.get(pdf_url, headers=HEADERS, stream=True, timeout=30) as r:
            r.raise_for_status()
            if "application/pdf" not in r.headers.get("Content-Type", ""):
                print(f"⚠️  Not a PDF ({r.headers.get('Content-Type')}). Skipping.")
                return False

            with open(pdf_path, "wb") as f:
                for chunk in r.iter_content(chunk_size=8192):
                    f.write(chunk)
        print(f"✅ Saved: {pdf_path}")
        return True

    except requests.RequestException as e:
        print(f"❌ Error downloading '{filename_base}': {e}")
        return False


# --- Scraping Process ---
scraped_data = []
for page in range(START_PAGE, END_PAGE + 1):
    page_data = fetch_page(page, BASE_PAYLOAD)
    if not page_data or not page_data.get("data"):
        print(f"⚠️  No data on page {page}, stopping.")
        break
    scraped_data.extend(page_data["data"])
    time.sleep(REQUEST_DELAY)

print(f"\n📊 Scraping complete. Total documents: {len(scraped_data)}")

if scraped_data:
    json_file = save_json(scraped_data, START_PAGE, END_PAGE)
    print(f"💾 Data saved to: {json_file}")

    print("\n🚀 Starting PDF downloads...")
    downloaded = sum(download_pdf(doc, i, len(scraped_data))
                     for i, doc in enumerate(scraped_data))
    print(f"\n🎉 PDF download complete: {downloaded}/{len(scraped_data)} successful.")
else:
    print("⚠️  No data scraped, skipping PDF downloads.")
# Out:
# Starting document metadata scraping...
# 🔎 Requesting page 1 ...
# 🔎 Requesting page 2 ...
# 🔎 Requesting page 3 ...
#
# 📊 Scraping complete. Total documents: 30
# 💾 Data saved to: output/ncar_crawl_page1-3_(20.10.2025).json
#
# 🚀 Starting PDF downloads...
# ⬇️  Downloading (1/30): تعديل-المادتين-8-11-من-تنظيم-صندوق-التنمية-الوطني-لعام-1439هـ_284
# ✅ Saved: NCAR_PDFs\تعديل-المادتين-8-11-من-تنظيم-صندوق-التنمية-الوطني-لعام-1439هـ_284.pdf
# ⬇️  Downloading (2/30): النظام-الأساس-لمؤسسة-مركز-الرياض-للتقنية-الحيوية-لعام-1447هـ_31971
# ✅ Saved: NCAR_PDFs\النظام-الأساس-لمؤسسة-مركز-الرياض-للتقنية-الحيوية-لعام-1447هـ_31971.pdf
# ⬇️  Downloading (3/30): تنظيم-المعهد-الوطني-لأبحاث-الصحة-لعام-1447هـ_266
# ✅ Saved: NCAR_PDFs\تنظيم-المعهد-الوطني-لأبحاث-الصحة-لعام-1447هـ_266.pdf
# ⬇️  Downloading (4/30): إنشاء-فرع-لجامعة-نيو-هيفن-بمدينة-الرياض_270
# ✅ Saved: NCAR_PDFs\إنشاء-فرع-لجامعة-نيو-هيفن-بمدينة-الرياض_270.pdf
# ⬇️  Downloading (5/30): ضم-الهيئة-العامة-للولاية-على-أموال-القاصرين-ومن-في-حكمهم-إلى-عضوية-اللجنة-الدائمة-لمكافحة-غسل-الأموا_271
# ✅ Saved: NCAR_PDFs\ضم-الهيئة-العامة-للولاية-على-أموال-القاصرين-ومن-في-حكمهم-إلى-عضوية-اللجنة-الدائمة-لمكافحة-غسل-الأموا_271.pdf
# ⬇️  Downloading (6/30): تحديد-المقصود-بعبارة-الضابط-الموصى-بترقيته-الواردة-في-الفقرة-أ-من-المادة-25-من-نظام-خدمة-الضباط-لعام_252
# ✅ Saved: NCAR_PDFs\تحديد-المقصود-بعبارة-الضابط-الموصى-بترقيته-الواردة-في-الفقرة-أ-من-المادة-25-من-نظام-خدمة-الضباط-لعام_252.pdf
# ⬇️  Downloading (7/30): آلية-مشاركة-الجهات-الحكومية-في-معارض-الكتاب-الدولية-لعام-1447هـ_24939
# ✅ Saved: NCAR_PDFs\آلية-مشاركة-الجهات-الحكومية-في-معارض-الكتاب-الدولية-لعام-1447هـ_24939.pdf
# ⬇️  Downloading (8/30): إضافة-صلاحية-تحديد-المقابل-المالي-لعمل-المرافقين-والمرافقات-للعمالة-الوافدة-النظامية-في-المملكة-لوزي_229
# ✅ Saved: NCAR_PDFs\إضافة-صلاحية-تحديد-المقابل-المالي-لعمل-المرافقين-والمرافقات-للعمالة-الوافدة-النظامية-في-المملكة-لوزي_229.pdf
# ⬇️  Downloading (9/30): تعديل-الفقرة-1-من-المادة-4-من-تنظيم-هيئة-المدن-والمناطق-الاقتصادية-الخاصة-لعام-1431هـ_أ76
# ✅ Saved: NCAR_PDFs\تعديل-الفقرة-1-من-المادة-4-من-تنظيم-هيئة-المدن-والمناطق-الاقتصادية-الخاصة-لعام-1431هـ_أ76.pdf
# ⬇️  Downloading (10/30): تنظيم-المركز-الوطني-لسلامة-النقل-لعام-1447هـ_212
# ✅ Saved: NCAR_PDFs\تنظيم-المركز-الوطني-لسلامة-النقل-لعام-1447هـ_212.pdf
# ⬇️  Downloading (11/30): إضافة-ممثل-لكل-من-هيئة-تنمية-البحث-والتطوير-والابتكار-وهيئة-فنون-الطهي-والهيئة-العامة-للأمن-الغذائي-_216
# ✅ Saved: NCAR_PDFs\إضافة-ممثل-لكل-من-هيئة-تنمية-البحث-والتطوير-والابتكار-وهيئة-فنون-الطهي-والهيئة-العامة-للأمن-الغذائي-_216.pdf
# ⬇️  Downloading (12/30): نظام-نزع-ملكية-العقارات-للمصلحة-العامة-ووضع-اليد-المؤقت-على-العقارات-لعام-1447هـ_م56
# ✅ Saved: NCAR_PDFs\نظام-نزع-ملكية-العقارات-للمصلحة-العامة-ووضع-اليد-المؤقت-على-العقارات-لعام-1447هـ_م56.pdf
# ⬇️  Downloading (13/30): Adding-Paragraph-13-to-the-rules-and-conditions-for-verifying-proof-of-origin-for-the-year-1442-AH_1447-99-303
# ✅ Saved: NCAR_PDFs\Adding-Paragraph-13-to-the-rules-and-conditions-for-verifying-proof-of-origin-for-the-year-1442-AH_1447-99-303.pdf
# ⬇️  Downloading (14/30): إنشاء-فرع-لجامعة-الأعمال-والتكنولوجيا-الأهلية-بمحافظة-ينبع_198
# ✅ Saved: NCAR_PDFs\إنشاء-فرع-لجامعة-الأعمال-والتكنولوجيا-الأهلية-بمحافظة-ينبع_198.pdf
# ⬇️  Downloading (15/30): تحديد-النطاق-الجغرافي-لمحمية-مجامع-الهضب_197
# ✅ Saved: NCAR_PDFs\تحديد-النطاق-الجغرافي-لمحمية-مجامع-الهضب_197.pdf
# ⬇️  Downloading (16/30): قواعد-تحديد-درجات-إركاب-الموظفين-والعاملين-في-الأجهزة-العامة-من-مدنيين-وعسكريين-لعام-1447هـ_196
# ✅ Saved: NCAR_PDFs\قواعد-تحديد-درجات-إركاب-الموظفين-والعاملين-في-الأجهزة-العامة-من-مدنيين-وعسكريين-لعام-1447هـ_196.pdf
# ⬇️  Downloading (17/30): إحلال-عبارة-وزارة-البلديات-والإسكان-محل-عبارة-وزارة-الشؤون-البلدية-والقروية-والإسكان-وإحلال-عبارة-وز_181
# ✅ Saved: NCAR_PDFs\إحلال-عبارة-وزارة-البلديات-والإسكان-محل-عبارة-وزارة-الشؤون-البلدية-والقروية-والإسكان-وإحلال-عبارة-وز_181.pdf
# ⬇️  Downloading (18/30): تعديل-المادة-74-من-نظام-المرور-لعام-1428هـ_م50
# ✅ Saved: NCAR_PDFs\تعديل-المادة-74-من-نظام-المرور-لعام-1428هـ_م50.pdf
# ⬇️  Downloading (19/30): نظام-الحرف-والصناعات-اليدوية-لعام-1447هـ_م49
# ✅ Saved: NCAR_PDFs\نظام-الحرف-والصناعات-اليدوية-لعام-1447هـ_م49.pdf
# ⬇️  Downloading (20/30): يجوز-لوزير-التجارة-في-الحالات-التي-يقدرها-تعيين-جميع-أعضاء-مجلس-إدارة-الغرفة-التجارية_م51
# ✅ Saved: NCAR_PDFs\يجوز-لوزير-التجارة-في-الحالات-التي-يقدرها-تعيين-جميع-أعضاء-مجلس-إدارة-الغرفة-التجارية_م51.pdf
# ⬇️  Downloading (21/30): تولي-هيئة-التراث-تنظيم-نشاط-الحرف-والصناعات-اليدوية-وفقا-لما-يحدده-نظام-الحرف-والصناعات-اليدوية_157
# ✅ Saved: NCAR_PDFs\تولي-هيئة-التراث-تنظيم-نشاط-الحرف-والصناعات-اليدوية-وفقا-لما-يحدده-نظام-الحرف-والصناعات-اليدوية_157.pdf
# ⬇️  Downloading (22/30): إضافة-فقرة-إلى-البند-ثالثا-من-إعادة-تنظيم-إجراءات-عملية-نشر-الأنظمة-في-الجريدة-الرسمية-لعام-1425هـ_159
# ✅ Saved: NCAR_PDFs\إضافة-فقرة-إلى-البند-ثالثا-من-إعادة-تنظيم-إجراءات-عملية-نشر-الأنظمة-في-الجريدة-الرسمية-لعام-1425هـ_159.pdf
# ⬇️  Downloading (23/30): الاشتراطات-البلدية-لتصريح-إشغال-رصيف-لعام-1447هـ_14700073988
# ✅ Saved: NCAR_PDFs\الاشتراطات-البلدية-لتصريح-إشغال-رصيف-لعام-1447هـ_14700073988.pdf
# ⬇️  Downloading (24/30): حذف-المادة-7-وتعديل-المواد-8-9-11-13-15-من-تنظيم-الهيئة-السعودية-للمحامين-لعام-1436هـ_143
# ✅ Saved: NCAR_PDFs\حذف-المادة-7-وتعديل-المواد-8-9-11-13-15-من-تنظيم-الهيئة-السعودية-للمحامين-لعام-1436هـ_143.pdf
# ⬇️  Downloading (25/30): تمديد-العمل-بوجوب-التقدم-إلى-مكتب-العمل-قبل-رفع-الدعوى-العمالية-أمام-المحاكم-العمالية-لمدة-سنة-من-تا_141
# ✅ Saved: NCAR_PDFs\تمديد-العمل-بوجوب-التقدم-إلى-مكتب-العمل-قبل-رفع-الدعوى-العمالية-أمام-المحاكم-العمالية-لمدة-سنة-من-تا_141.pdf
# ⬇️  Downloading (26/30): اعتماد-الترقيم-المستخدم-في-العنوان-الوطني-في-ترقيم-العقارات-بموجب-قواعد-تسمية-الشوارع-والميادين-وترق_126
# ✅ Saved: NCAR_PDFs\اعتماد-الترقيم-المستخدم-في-العنوان-الوطني-في-ترقيم-العقارات-بموجب-قواعد-تسمية-الشوارع-والميادين-وترق_126.pdf
# ⬇️  Downloading (27/30): تعديل-المادتين-5-10-من-تنظيم-المركز-الوطني-للأرصاد-لعام-1440هـ_127
# ✅ Saved: NCAR_PDFs\تعديل-المادتين-5-10-من-تنظيم-المركز-الوطني-للأرصاد-لعام-1440هـ_127.pdf
# ⬇️  Downloading (28/30): نظام-الإحصاء-لعام-1447هـ_م29
# ✅ Saved: NCAR_PDFs\نظام-الإحصاء-لعام-1447هـ_م29.pdf
# ⬇️  Downloading (29/30): تعديل-الفقرتين-4-و-5-من-المادة-6-من-اللائحة-التنفيذية-لنظام-مهنة-المحاسبة-والمراجعة-لعام-1442هـ_28
# ✅ Saved: NCAR_PDFs\تعديل-الفقرتين-4-و-5-من-المادة-6-من-اللائحة-التنفيذية-لنظام-مهنة-المحاسبة-والمراجعة-لعام-1442هـ_28.pdf
# ⬇️  Downloading (30/30): تعديل-المواد-1-2-4-من-تنظيم-الهيئة-السعودية-للبحر-الأحمر-لعام-1445هـ_78
# ✅ Saved: NCAR_PDFs\تعديل-المواد-1-2-4-من-تنظيم-الهيئة-السعودية-للبحر-الأحمر-لعام-1445هـ_78.pdf
#
# 🎉 PDF download complete: 30/30 successful.
