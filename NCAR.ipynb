# %%
# @title 1. Setup Environment
import requests
import json
import time
import os
import re # For cleaning filenames
from IPython.display import display, HTML # For displaying output in Colab

print("Setting up environment...")

# Create a directory to save PDFs if it doesn't exist
pdf_output_dir = "downloaded_pdfs"
if not os.path.exists(pdf_output_dir):
    os.makedirs(pdf_output_dir)
    print(f"Created directory: '{pdf_output_dir}' for PDFs.")
else:
    print(f"Directory '{pdf_output_dir}' already exists.")

print("Environment setup complete.")


# @title 2. Scraping All Document Metadata
print("Starting document metadata scraping...")

base_api_url = "https://ncar.gov.sa/api/index.php/api/documents/document-search"
all_scraped_data = []

# --- Configuration for Scraping ---
items_per_page = 10 # Each page has 10 items
sort_by = "approveDate"
sort_order = "DESC"

# Your identified base payload
base_payload = {
    "approveTool_id": None,
    "documentCategory_id": None,
    "name": None,
    "ApproveDate": None,
    "PublishingStatus": None,
    "alphabeticalCategory_id": None,
    "alphabeticalSubCategory_id": [],
    "alphabeticalTopic_id": None,
    "approveDate_from": None,
    "approveDate_to": None,
    "generalCategory_id": [],
    "governmentalAgency_childId": [],
    "governmentalAgency_id": None,
    "identical": 1,
    "is_printed": None,
    "is_translated": None,
    "is_valid": None,
    "number": None,
    "omAlQourah_date": None,
    "omAlQourah_version": None,
    "particularCategory_id": [],
    "releaseOrgId": None
}

# --- Function to fetch a single page of documents ---
def fetch_page(page_num, current_payload):
    url = f"{base_api_url}/{page_num}/{items_per_page}/{sort_by}/{sort_order}"

    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36",
        "Referer": "https://ncar.gov.sa/rules-regulations"
    }

    print(f"  Requesting page {page_num} from: {url}")
    try:
        response = requests.post(url, headers=headers, json=current_payload)
        response.raise_for_status() # Raise an HTTPError for bad responses
        return response.json() # Parse the JSON response
    except requests.exceptions.RequestException as e:
        print(f"  Error fetching page {page_num}: {e}")
        return None

# --- Main Scraping Loop ---
current_page = 1
search_payload = base_payload.copy()

while True:
    page_data_response = fetch_page(current_page, search_payload)

    if page_data_response is None:
        print("  Failed to retrieve data for this page. Stopping scraping.")
        break

    documents_on_page = page_data_response.get("data")

    if not documents_on_page:
        print(f"  No more data found on page {current_page}. Stopping pagination.")
        break

    all_scraped_data.extend(documents_on_page) # Add all documents from the current page

    current_page += 1
    time.sleep(0.5) # Be polite, a short delay between API requests

print(f"Scraping complete! Total documents scraped: {len(all_scraped_data)}.")

# Optional: Save the scraped metadata to a JSON file (useful for debugging or later use)
# with open("ncar_documents.json", "w", encoding="utf-8") as f:
#     json.dump(all_scraped_data, f, ensure_ascii=False, indent=4)
# print("Scraped metadata saved to 'ncar_documents.json'.")


# @title 3. Downloading All PDF Files
print("\nStarting PDF download process...")

# Base URL parts for PDF resources
base_pdf_url_prefix = "https://ncar.gov.sa/api/index.php/resource/"
base_pdf_url_suffix = "/Documents/OriginalAttachPath"

# --- Function to sanitize filenames ---
def sanitize_filename(name):
    """
    Cleans a string to be suitable for a filename.
    Handles Unicode escape sequences and removes invalid characters.
    """
    # Attempt to decode Unicode escape sequences if present
    try:
        name = name.encode('latin1').decode('unicode_escape')
    except (UnicodeEncodeError, UnicodeDecodeError):
        pass # If not a unicode escape sequence, keep as is

    # Remove characters that are not letters, numbers, hyphens, underscores, or spaces
    s = re.sub(r'[^\w\s-]', '', name).strip()
    # Replace multiple spaces with a single hyphen
    s = re.sub(r'[\s]+', '-', s)
    # Truncate to a reasonable length (e.g., 100 characters) to avoid OS limits
    return s[:100]

downloaded_count = 0
total_documents = len(all_scraped_data)

if total_documents == 0:
    print("No documents were scraped. Cannot proceed with PDF downloads.")
else:
    for i, doc in enumerate(all_scraped_data):
        # The 'id' field contains the encrypted part needed for the PDF URL
        encrypted_part = doc.get("id")

        # Skip if the 'id' (encrypted part) is missing
        if not encrypted_part:
            print(f"  Skipping document {i+1}: No 'id' (encrypted part) found.")
            continue

        # Construct the full PDF download URL
        pdf_url = f"{base_pdf_url_prefix}{encrypted_part}{base_pdf_url_suffix}"

        # Generate a descriptive filename using English title and document number
        doc_title_en = doc.get("title_en", f"document_{i+1}") # Fallback title if 'title_en' is missing
        doc_number = doc.get("number", "") # Can be empty

        sanitized_title = sanitize_filename(doc_title_en)
        sanitized_number = sanitize_filename(doc_number) if doc_number else ""

        if sanitized_number:
            filename_base = f"{sanitized_title}_{sanitized_number}"
        else:
            filename_base = sanitized_title

        pdf_filename = os.path.join(pdf_output_dir, f"{filename_base}.pdf")

        print(f"  Downloading ({i+1}/{total_documents}): '{filename_base}'")

        headers = {
            "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36",
            "Referer": "https://ncar.gov.sa/rules-regulations"
        }

        try:
            # Use stream=True for efficient downloading of potentially large files
            with requests.get(pdf_url, headers=headers, stream=True) as r:
                r.raise_for_status() # Check for HTTP errors

                # Perform a basic check for PDF content type
                content_type = r.headers.get('Content-Type', '')
                if 'application/pdf' not in content_type and 'octet-stream' not in content_type:
                    print(f"    Warning: Expected PDF for '{filename_base}', but got Content-Type: '{content_type}'. Skipping.")
                    continue

                with open(pdf_filename, 'wb') as f:
                    for chunk in r.iter_content(chunk_size=8192): # Download in chunks
                        f.write(chunk)
                print(f"    Successfully saved: '{pdf_filename}'")
                downloaded_count += 1

        except requests.exceptions.RequestException as e:
            print(f"    Error downloading '{filename_base}': {e}")
        except Exception as e:
            print(f"    An unexpected error occurred for '{filename_base}': {e}")

        time.sleep(0.5) # Polite delay between downloads

    print(f"\nPDF download complete! Total PDFs downloaded: {downloaded_count} out of {total_documents} found.")

# Optional: Provide a way to download the entire 'downloaded_pdfs' folder from Colab
print("\n---")
print("All PDFs are saved in the 'downloaded_pdfs' folder in your Colab environment.")
print("To download them to your local computer, run the following in a new Colab cell:")
display(HTML("""
<pre>
from google.colab import files
# !zip -r /content/downloaded_pdfs.zip /content/downloaded_pdfs
files.download('/content/downloaded_pdfs.zip')
</pre>
"""))
# Out:
# Setting up environment...
# Created directory: 'downloaded_pdfs' for PDFs.
# Environment setup complete.
# Starting document metadata scraping...
#   Requesting page 1 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/1/10/approveDate/DESC
#   Requesting page 2 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/2/10/approveDate/DESC
#   Requesting page 3 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/3/10/approveDate/DESC
#   Requesting page 4 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/4/10/approveDate/DESC
#   Requesting page 5 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/5/10/approveDate/DESC
#   Requesting page 6 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/6/10/approveDate/DESC
#   Requesting page 7 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/7/10/approveDate/DESC
#   Requesting page 8 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/8/10/approveDate/DESC
#   Requesting page 9 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/9/10/approveDate/DESC
#   Requesting page 10 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/10/10/approveDate/DESC
#   Requesting page 11 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/11/10/approveDate/DESC
#   Requesting page 12 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/12/10/approveDate/DESC
#   Requesting page 13 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/13/10/approveDate/DESC
#   Requesting page 14 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/14/10/approveDate/DESC
#   Requesting page 15 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/15/10/approveDate/DESC
#   Requesting page 16 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/16/10/approveDate/DESC
#   Requesting page 17 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/17/10/approveDate/DESC
#   Requesting page 18 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/18/10/approveDate/DESC
#   Requesting page 19 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/19/10/approveDate/DESC
#   Requesting page 20 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/20/10/approveDate/DESC
#   Requesting page 21 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/21/10/approveDate/DESC
#   Requesting page 22 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/22/10/approveDate/DESC
#   Requesting page 23 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/23/10/approveDate/DESC
#   Requesting page 24 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/24/10/approveDate/DESC
#   Requesting page 25 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/25/10/approveDate/DESC
#   Requesting page 26 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/26/10/approveDate/DESC
#   Requesting page 27 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/27/10/approveDate/DESC
#   Requesting page 28 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/28/10/approveDate/DESC
#   Requesting page 29 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/29/10/approveDate/DESC
#   Requesting page 30 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/30/10/approveDate/DESC
#   Requesting page 31 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/31/10/approveDate/DESC
#   Requesting page 32 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/32/10/approveDate/DESC
#   Requesting page 33 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/33/10/approveDate/DESC
#   Requesting page 34 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/34/10/approveDate/DESC
#   Requesting page 35 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/35/10/approveDate/DESC
#   Requesting page 36 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/36/10/approveDate/DESC
#   Requesting page 37 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/37/10/approveDate/DESC
#   Requesting page 38 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/38/10/approveDate/DESC
#   Requesting page 39 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/39/10/approveDate/DESC
#   Requesting page 40 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/40/10/approveDate/DESC
#   Requesting page 41 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/41/10/approveDate/DESC
#   Requesting page 42 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/42/10/approveDate/DESC
#   Requesting page 43 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/43/10/approveDate/DESC
#   Requesting page 44 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/44/10/approveDate/DESC
#   Requesting page 45 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/45/10/approveDate/DESC
#   Requesting page 46 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/46/10/approveDate/DESC
#   Requesting page 47 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/47/10/approveDate/DESC
#   Requesting page 48 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/48/10/approveDate/DESC
#   Requesting page 49 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/49/10/approveDate/DESC
#   Requesting page 50 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/50/10/approveDate/DESC
#   Requesting page 51 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/51/10/approveDate/DESC
#   Requesting page 52 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/52/10/approveDate/DESC
#   Requesting page 53 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/53/10/approveDate/DESC
#   Requesting page 54 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/54/10/approveDate/DESC
#   Requesting page 55 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/55/10/approveDate/DESC
#   Requesting page 56 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/56/10/approveDate/DESC
#   Requesting page 57 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/57/10/approveDate/DESC
#   Requesting page 58 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/58/10/approveDate/DESC
#   Requesting page 59 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/59/10/approveDate/DESC
#   Requesting page 60 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/60/10/approveDate/DESC
#   Requesting page 61 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/61/10/approveDate/DESC
#   Requesting page 62 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/62/10/approveDate/DESC
#   Requesting page 63 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/63/10/approveDate/DESC
#   Requesting page 64 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/64/10/approveDate/DESC
#   Requesting page 65 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/65/10/approveDate/DESC
#   Requesting page 66 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/66/10/approveDate/DESC
#   Requesting page 67 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/67/10/approveDate/DESC
#   Requesting page 68 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/68/10/approveDate/DESC
#   Requesting page 69 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/69/10/approveDate/DESC
#   Requesting page 70 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/70/10/approveDate/DESC
#   Requesting page 71 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/71/10/approveDate/DESC
#   Requesting page 72 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/72/10/approveDate/DESC
#   Requesting page 73 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/73/10/approveDate/DESC
#   Requesting page 74 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/74/10/approveDate/DESC
#   Requesting page 75 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/75/10/approveDate/DESC
#   Requesting page 76 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/76/10/approveDate/DESC
#   Requesting page 77 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/77/10/approveDate/DESC
#   Requesting page 78 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/78/10/approveDate/DESC
#   Requesting page 79 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/79/10/approveDate/DESC
#   Requesting page 80 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/80/10/approveDate/DESC
#   Requesting page 81 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/81/10/approveDate/DESC
#   Requesting page 82 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/82/10/approveDate/DESC
#   Requesting page 83 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/83/10/approveDate/DESC
#   Requesting page 84 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/84/10/approveDate/DESC
#   Requesting page 85 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/85/10/approveDate/DESC
#   Requesting page 86 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/86/10/approveDate/DESC
#   Requesting page 87 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/87/10/approveDate/DESC
#   Requesting page 88 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/88/10/approveDate/DESC
#   Requesting page 89 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/89/10/approveDate/DESC
#   Requesting page 90 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/90/10/approveDate/DESC
#   Requesting page 91 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/91/10/approveDate/DESC
#   Requesting page 92 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/92/10/approveDate/DESC
#   Requesting page 93 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/93/10/approveDate/DESC
#   Requesting page 94 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/94/10/approveDate/DESC
#   Requesting page 95 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/95/10/approveDate/DESC
#   Requesting page 96 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/96/10/approveDate/DESC
#   Requesting page 97 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/97/10/approveDate/DESC
#   Requesting page 98 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/98/10/approveDate/DESC
#   Requesting page 99 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/99/10/approveDate/DESC
#   Requesting page 100 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/100/10/approveDate/DESC
#   Requesting page 101 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/101/10/approveDate/DESC
#   Requesting page 102 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/102/10/approveDate/DESC
#   Requesting page 103 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/103/10/approveDate/DESC
#   Requesting page 104 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/104/10/approveDate/DESC
#   Requesting page 105 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/105/10/approveDate/DESC
#   Requesting page 106 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/106/10/approveDate/DESC
#   Requesting page 107 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/107/10/approveDate/DESC
#   Requesting page 108 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/108/10/approveDate/DESC
#   Requesting page 109 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/109/10/approveDate/DESC
#   Requesting page 110 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/110/10/approveDate/DESC
#   Requesting page 111 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/111/10/approveDate/DESC
#   Requesting page 112 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/112/10/approveDate/DESC
#   Requesting page 113 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/113/10/approveDate/DESC
#   Requesting page 114 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/114/10/approveDate/DESC
#   Requesting page 115 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/115/10/approveDate/DESC
#   Requesting page 116 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/116/10/approveDate/DESC

# %%
# @title 1. Scraping All Document Metadata (MUST RUN THIS FIRST if your session reset)

import requests
import json
import time
import os
import re # For cleaning filenames
from IPython.display import display, HTML # For displaying output in Colab

print("Starting document metadata scraping...")

# Ensure the PDF directory exists for consistency, though not directly used in this scrape cell
pdf_output_dir = "downloaded_pdfs"
if not os.path.exists(pdf_output_dir):
    os.makedirs(pdf_output_dir)

base_api_url = "https://ncar.gov.sa/api/index.php/api/documents/document-search"
global all_scraped_data # Make it global so other cells can access it
all_scraped_data = []

# --- Configuration for Scraping ---
items_per_page = 10
sort_by = "approveDate"
sort_order = "DESC"

base_payload = {
    "approveTool_id": None, "documentCategory_id": None, "name": None, "ApproveDate": None,
    "PublishingStatus": None, "alphabeticalCategory_id": None, "alphabeticalSubCategory_id": [],
    "alphabeticalTopic_id": None, "approveDate_from": None, "approveDate_to": None,
    "generalCategory_id": [], "governmentalAgency_childId": [], "governmentalAgency_id": None,
    "identical": 1, "is_printed": None, "is_translated": None, "is_valid": None,
    "number": None, "omAlQourah_date": None, "omAlQourah_version": None, "particularCategory_id": [],
    "releaseOrgId": None
}

def fetch_page(page_num, current_payload):
    url = f"{base_api_url}/{page_num}/{items_per_page}/{sort_by}/{sort_order}"
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36",
        "Referer": "https://ncar.gov.sa/rules-regulations"
    }
    print(f"  Requesting page {page_num} from: {url}")
    try:
        response = requests.post(url, headers=headers, json=current_payload)
        response.raise_for_status()
        return response.json()
    except requests.exceptions.RequestException as e:
        print(f"  Error fetching page {page_num}: {e}")
        return None

current_page = 1
search_payload = base_payload.copy()

while True:
    page_data_response = fetch_page(current_page, search_payload)
    if page_data_response is None:
        print("  Failed to retrieve data for this page. Stopping scraping.")
        break
    documents_on_page = page_data_response.get("data")
    if not documents_on_page:
        print(f"  No more data found on page {current_page}. Stopping pagination.")
        break
    all_scraped_data.extend(documents_on_page)
    current_page += 1
    time.sleep(0.5)

print(f"Scraping complete! Total documents scraped: {len(all_scraped_data)}.")

# Save the scraped metadata to a JSON file (essential for the next step)
with open("ncar_documents.json", "w", encoding="utf-8") as f:
    json.dump(all_scraped_data, f, ensure_ascii=False, indent=4)
print("Scraped metadata saved to 'ncar_documents.json'.")
print("Proceed to the next step to identify the missing files.")
# Out:
# Starting document metadata scraping...
#   Requesting page 1 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/1/10/approveDate/DESC
#   Requesting page 2 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/2/10/approveDate/DESC
#   Requesting page 3 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/3/10/approveDate/DESC
#   Requesting page 4 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/4/10/approveDate/DESC
#   Requesting page 5 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/5/10/approveDate/DESC
#   Requesting page 6 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/6/10/approveDate/DESC
#   Requesting page 7 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/7/10/approveDate/DESC
#   Requesting page 8 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/8/10/approveDate/DESC
#   Requesting page 9 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/9/10/approveDate/DESC
#   Requesting page 10 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/10/10/approveDate/DESC
#   Requesting page 11 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/11/10/approveDate/DESC
#   Requesting page 12 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/12/10/approveDate/DESC
#   Requesting page 13 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/13/10/approveDate/DESC
#   Requesting page 14 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/14/10/approveDate/DESC
#   Requesting page 15 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/15/10/approveDate/DESC
#   Requesting page 16 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/16/10/approveDate/DESC
#   Requesting page 17 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/17/10/approveDate/DESC
#   Requesting page 18 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/18/10/approveDate/DESC
#   Requesting page 19 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/19/10/approveDate/DESC
#   Requesting page 20 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/20/10/approveDate/DESC
#   Requesting page 21 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/21/10/approveDate/DESC
#   Requesting page 22 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/22/10/approveDate/DESC
#   Requesting page 23 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/23/10/approveDate/DESC
#   Requesting page 24 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/24/10/approveDate/DESC
#   Requesting page 25 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/25/10/approveDate/DESC
#   Requesting page 26 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/26/10/approveDate/DESC
#   Requesting page 27 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/27/10/approveDate/DESC
#   Requesting page 28 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/28/10/approveDate/DESC
#   Requesting page 29 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/29/10/approveDate/DESC
#   Requesting page 30 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/30/10/approveDate/DESC
#   Requesting page 31 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/31/10/approveDate/DESC
#   Requesting page 32 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/32/10/approveDate/DESC
#   Requesting page 33 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/33/10/approveDate/DESC
#   Requesting page 34 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/34/10/approveDate/DESC
#   Requesting page 35 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/35/10/approveDate/DESC
#   Requesting page 36 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/36/10/approveDate/DESC
#   Requesting page 37 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/37/10/approveDate/DESC
#   Requesting page 38 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/38/10/approveDate/DESC
#   Requesting page 39 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/39/10/approveDate/DESC
#   Requesting page 40 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/40/10/approveDate/DESC
#   Requesting page 41 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/41/10/approveDate/DESC
#   Requesting page 42 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/42/10/approveDate/DESC
#   Requesting page 43 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/43/10/approveDate/DESC
#   Requesting page 44 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/44/10/approveDate/DESC
#   Requesting page 45 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/45/10/approveDate/DESC
#   Requesting page 46 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/46/10/approveDate/DESC
#   Requesting page 47 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/47/10/approveDate/DESC
#   Requesting page 48 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/48/10/approveDate/DESC
#   Requesting page 49 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/49/10/approveDate/DESC
#   Requesting page 50 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/50/10/approveDate/DESC
#   Requesting page 51 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/51/10/approveDate/DESC
#   Requesting page 52 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/52/10/approveDate/DESC
#   Requesting page 53 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/53/10/approveDate/DESC
#   Requesting page 54 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/54/10/approveDate/DESC
#   Requesting page 55 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/55/10/approveDate/DESC
#   Requesting page 56 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/56/10/approveDate/DESC
#   Requesting page 57 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/57/10/approveDate/DESC
#   Requesting page 58 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/58/10/approveDate/DESC
#   Requesting page 59 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/59/10/approveDate/DESC
#   Requesting page 60 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/60/10/approveDate/DESC
#   Requesting page 61 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/61/10/approveDate/DESC
#   Requesting page 62 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/62/10/approveDate/DESC
#   Requesting page 63 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/63/10/approveDate/DESC
#   Requesting page 64 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/64/10/approveDate/DESC
#   Requesting page 65 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/65/10/approveDate/DESC
#   Requesting page 66 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/66/10/approveDate/DESC
#   Requesting page 67 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/67/10/approveDate/DESC
#   Requesting page 68 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/68/10/approveDate/DESC
#   Requesting page 69 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/69/10/approveDate/DESC
#   Requesting page 70 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/70/10/approveDate/DESC
#   Requesting page 71 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/71/10/approveDate/DESC
#   Requesting page 72 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/72/10/approveDate/DESC
#   Requesting page 73 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/73/10/approveDate/DESC
#   Requesting page 74 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/74/10/approveDate/DESC
#   Requesting page 75 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/75/10/approveDate/DESC
#   Requesting page 76 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/76/10/approveDate/DESC
#   Requesting page 77 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/77/10/approveDate/DESC
#   Requesting page 78 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/78/10/approveDate/DESC
#   Requesting page 79 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/79/10/approveDate/DESC
#   Requesting page 80 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/80/10/approveDate/DESC
#   Requesting page 81 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/81/10/approveDate/DESC
#   Requesting page 82 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/82/10/approveDate/DESC
#   Requesting page 83 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/83/10/approveDate/DESC
#   Requesting page 84 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/84/10/approveDate/DESC
#   Requesting page 85 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/85/10/approveDate/DESC
#   Requesting page 86 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/86/10/approveDate/DESC
#   Requesting page 87 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/87/10/approveDate/DESC
#   Requesting page 88 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/88/10/approveDate/DESC
#   Requesting page 89 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/89/10/approveDate/DESC
#   Requesting page 90 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/90/10/approveDate/DESC
#   Requesting page 91 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/91/10/approveDate/DESC
#   Requesting page 92 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/92/10/approveDate/DESC
#   Requesting page 93 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/93/10/approveDate/DESC
#   Requesting page 94 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/94/10/approveDate/DESC
#   Requesting page 95 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/95/10/approveDate/DESC
#   Requesting page 96 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/96/10/approveDate/DESC
#   Requesting page 97 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/97/10/approveDate/DESC
#   Requesting page 98 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/98/10/approveDate/DESC
#   Requesting page 99 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/99/10/approveDate/DESC
#   Requesting page 100 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/100/10/approveDate/DESC
#   Requesting page 101 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/101/10/approveDate/DESC
#   Requesting page 102 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/102/10/approveDate/DESC
#   Requesting page 103 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/103/10/approveDate/DESC
#   Requesting page 104 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/104/10/approveDate/DESC
#   Requesting page 105 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/105/10/approveDate/DESC
#   Requesting page 106 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/106/10/approveDate/DESC
#   Requesting page 107 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/107/10/approveDate/DESC
#   Requesting page 108 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/108/10/approveDate/DESC
#   Requesting page 109 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/109/10/approveDate/DESC
#   Requesting page 110 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/110/10/approveDate/DESC
#   Requesting page 111 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/111/10/approveDate/DESC
#   Requesting page 112 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/112/10/approveDate/DESC
#   Requesting page 113 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/113/10/approveDate/DESC
#   Requesting page 114 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/114/10/approveDate/DESC
#   Requesting page 115 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/115/10/approveDate/DESC
#   Requesting page 116 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/116/10/approveDate/DESC
#   Requesting page 117 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/117/10/approveDate/DESC
#   Requesting page 118 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/118/10/approveDate/DESC
#   Requesting page 119 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/119/10/approveDate/DESC
#   Requesting page 120 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/120/10/approveDate/DESC
#   Requesting page 121 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/121/10/approveDate/DESC
#   Requesting page 122 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/122/10/approveDate/DESC
#   Requesting page 123 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/123/10/approveDate/DESC
#   Requesting page 124 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/124/10/approveDate/DESC
#   Requesting page 125 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/125/10/approveDate/DESC
#   Requesting page 126 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/126/10/approveDate/DESC
#   Requesting page 127 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/127/10/approveDate/DESC
#   Requesting page 128 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/128/10/approveDate/DESC
#   Requesting page 129 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/129/10/approveDate/DESC
#   Requesting page 130 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/130/10/approveDate/DESC
#   Requesting page 131 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/131/10/approveDate/DESC
#   Requesting page 132 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/132/10/approveDate/DESC
#   Requesting page 133 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/133/10/approveDate/DESC
#   Requesting page 134 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/134/10/approveDate/DESC
#   Requesting page 135 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/135/10/approveDate/DESC
#   Requesting page 136 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/136/10/approveDate/DESC
#   Requesting page 137 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/137/10/approveDate/DESC
#   Requesting page 138 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/138/10/approveDate/DESC
#   Requesting page 139 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/139/10/approveDate/DESC
#   Requesting page 140 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/140/10/approveDate/DESC
#   Requesting page 141 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/141/10/approveDate/DESC
#   Requesting page 142 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/142/10/approveDate/DESC
#   Requesting page 143 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/143/10/approveDate/DESC
#   Requesting page 144 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/144/10/approveDate/DESC
#   Requesting page 145 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/145/10/approveDate/DESC
#   Requesting page 146 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/146/10/approveDate/DESC
#   Requesting page 147 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/147/10/approveDate/DESC
#   Requesting page 148 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/148/10/approveDate/DESC
#   Requesting page 149 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/149/10/approveDate/DESC
#   Requesting page 150 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/150/10/approveDate/DESC
#   Requesting page 151 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/151/10/approveDate/DESC
#   Requesting page 152 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/152/10/approveDate/DESC
#   Requesting page 153 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/153/10/approveDate/DESC
#   Requesting page 154 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/154/10/approveDate/DESC
#   Requesting page 155 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/155/10/approveDate/DESC
#   Requesting page 156 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/156/10/approveDate/DESC
#   Requesting page 157 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/157/10/approveDate/DESC
#   Requesting page 158 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/158/10/approveDate/DESC
#   Requesting page 159 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/159/10/approveDate/DESC
#   Requesting page 160 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/160/10/approveDate/DESC
#   Requesting page 161 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/161/10/approveDate/DESC
#   Requesting page 162 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/162/10/approveDate/DESC
#   Requesting page 163 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/163/10/approveDate/DESC
#   Requesting page 164 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/164/10/approveDate/DESC
#   Requesting page 165 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/165/10/approveDate/DESC
#   Requesting page 166 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/166/10/approveDate/DESC
#   Requesting page 167 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/167/10/approveDate/DESC
#   Requesting page 168 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/168/10/approveDate/DESC
#   Requesting page 169 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/169/10/approveDate/DESC
#   Requesting page 170 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/170/10/approveDate/DESC
#   Requesting page 171 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/171/10/approveDate/DESC
#   Requesting page 172 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/172/10/approveDate/DESC
#   Requesting page 173 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/173/10/approveDate/DESC
#   Requesting page 174 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/174/10/approveDate/DESC
#   Requesting page 175 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/175/10/approveDate/DESC
#   Requesting page 176 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/176/10/approveDate/DESC
#   Requesting page 177 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/177/10/approveDate/DESC
#   Requesting page 178 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/178/10/approveDate/DESC
#   Requesting page 179 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/179/10/approveDate/DESC
#   Requesting page 180 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/180/10/approveDate/DESC
#   Requesting page 181 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/181/10/approveDate/DESC
#   Requesting page 182 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/182/10/approveDate/DESC
#   Requesting page 183 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/183/10/approveDate/DESC
#   Requesting page 184 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/184/10/approveDate/DESC
#   Requesting page 185 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/185/10/approveDate/DESC
#   Requesting page 186 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/186/10/approveDate/DESC
#   Requesting page 187 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/187/10/approveDate/DESC
#   Requesting page 188 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/188/10/approveDate/DESC
#   Requesting page 189 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/189/10/approveDate/DESC
#   Requesting page 190 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/190/10/approveDate/DESC
#   Requesting page 191 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/191/10/approveDate/DESC
#   Requesting page 192 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/192/10/approveDate/DESC
#   Requesting page 193 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/193/10/approveDate/DESC
#   Requesting page 194 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/194/10/approveDate/DESC
#   Requesting page 195 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/195/10/approveDate/DESC
#   Requesting page 196 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/196/10/approveDate/DESC
#   Requesting page 197 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/197/10/approveDate/DESC
#   Requesting page 198 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/198/10/approveDate/DESC
#   Requesting page 199 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/199/10/approveDate/DESC
#   Requesting page 200 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/200/10/approveDate/DESC
#   Requesting page 201 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/201/10/approveDate/DESC
#   Requesting page 202 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/202/10/approveDate/DESC
#   Requesting page 203 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/203/10/approveDate/DESC
#   Requesting page 204 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/204/10/approveDate/DESC
#   Requesting page 205 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/205/10/approveDate/DESC
#   Requesting page 206 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/206/10/approveDate/DESC
#   Requesting page 207 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/207/10/approveDate/DESC
#   Requesting page 208 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/208/10/approveDate/DESC
#   Requesting page 209 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/209/10/approveDate/DESC
#   Requesting page 210 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/210/10/approveDate/DESC
#   Requesting page 211 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/211/10/approveDate/DESC
#   Requesting page 212 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/212/10/approveDate/DESC
#   Requesting page 213 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/213/10/approveDate/DESC
#   Requesting page 214 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/214/10/approveDate/DESC
#   Requesting page 215 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/215/10/approveDate/DESC
#   Requesting page 216 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/216/10/approveDate/DESC
#   Requesting page 217 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/217/10/approveDate/DESC
#   Requesting page 218 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/218/10/approveDate/DESC
#   Requesting page 219 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/219/10/approveDate/DESC
#   Requesting page 220 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/220/10/approveDate/DESC
#   Requesting page 221 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/221/10/approveDate/DESC
#   Requesting page 222 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/222/10/approveDate/DESC
#   Requesting page 223 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/223/10/approveDate/DESC
#   Requesting page 224 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/224/10/approveDate/DESC
#   Requesting page 225 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/225/10/approveDate/DESC
#   Requesting page 226 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/226/10/approveDate/DESC
#   Requesting page 227 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/227/10/approveDate/DESC
#   Requesting page 228 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/228/10/approveDate/DESC
#   Requesting page 229 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/229/10/approveDate/DESC
#   Requesting page 230 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/230/10/approveDate/DESC
#   Requesting page 231 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/231/10/approveDate/DESC
#   Requesting page 232 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/232/10/approveDate/DESC
#   Requesting page 233 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/233/10/approveDate/DESC
#   Requesting page 234 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/234/10/approveDate/DESC
#   Requesting page 235 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/235/10/approveDate/DESC
#   Requesting page 236 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/236/10/approveDate/DESC
#   Requesting page 237 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/237/10/approveDate/DESC
#   Requesting page 238 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/238/10/approveDate/DESC
#   Requesting page 239 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/239/10/approveDate/DESC
#   Requesting page 240 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/240/10/approveDate/DESC
#   Requesting page 241 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/241/10/approveDate/DESC
#   Requesting page 242 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/242/10/approveDate/DESC
#   Requesting page 243 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/243/10/approveDate/DESC
#   Requesting page 244 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/244/10/approveDate/DESC
#   Requesting page 245 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/245/10/approveDate/DESC
#   Requesting page 246 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/246/10/approveDate/DESC
#   Requesting page 247 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/247/10/approveDate/DESC
#   Requesting page 248 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/248/10/approveDate/DESC
#   Requesting page 249 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/249/10/approveDate/DESC
#   Requesting page 250 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/250/10/approveDate/DESC
#   Requesting page 251 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/251/10/approveDate/DESC
#   Requesting page 252 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/252/10/approveDate/DESC
#   Requesting page 253 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/253/10/approveDate/DESC
#   Requesting page 254 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/254/10/approveDate/DESC
#   Requesting page 255 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/255/10/approveDate/DESC
#   Requesting page 256 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/256/10/approveDate/DESC
#   Requesting page 257 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/257/10/approveDate/DESC
#   Requesting page 258 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/258/10/approveDate/DESC
#   Requesting page 259 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/259/10/approveDate/DESC
#   Requesting page 260 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/260/10/approveDate/DESC
#   Requesting page 261 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/261/10/approveDate/DESC
#   Requesting page 262 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/262/10/approveDate/DESC
#   Requesting page 263 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/263/10/approveDate/DESC
#   Requesting page 264 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/264/10/approveDate/DESC
#   Requesting page 265 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/265/10/approveDate/DESC
#   Requesting page 266 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/266/10/approveDate/DESC
#   Requesting page 267 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/267/10/approveDate/DESC
#   Requesting page 268 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/268/10/approveDate/DESC
#   Requesting page 269 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/269/10/approveDate/DESC
#   Requesting page 270 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/270/10/approveDate/DESC
#   Requesting page 271 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/271/10/approveDate/DESC
#   Requesting page 272 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/272/10/approveDate/DESC
#   Requesting page 273 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/273/10/approveDate/DESC
#   Requesting page 274 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/274/10/approveDate/DESC
#   Requesting page 275 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/275/10/approveDate/DESC
#   Requesting page 276 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/276/10/approveDate/DESC
#   Requesting page 277 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/277/10/approveDate/DESC
#   Requesting page 278 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/278/10/approveDate/DESC
#   Requesting page 279 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/279/10/approveDate/DESC
#   Requesting page 280 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/280/10/approveDate/DESC
#   Requesting page 281 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/281/10/approveDate/DESC
#   Requesting page 282 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/282/10/approveDate/DESC
#   Requesting page 283 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/283/10/approveDate/DESC
#   Requesting page 284 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/284/10/approveDate/DESC
#   Requesting page 285 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/285/10/approveDate/DESC
#   Requesting page 286 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/286/10/approveDate/DESC
#   Requesting page 287 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/287/10/approveDate/DESC
#   Requesting page 288 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/288/10/approveDate/DESC
#   Requesting page 289 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/289/10/approveDate/DESC
#   Requesting page 290 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/290/10/approveDate/DESC
#   Requesting page 291 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/291/10/approveDate/DESC
#   Requesting page 292 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/292/10/approveDate/DESC
#   Requesting page 293 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/293/10/approveDate/DESC
#   Requesting page 294 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/294/10/approveDate/DESC
#   Requesting page 295 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/295/10/approveDate/DESC
#   Requesting page 296 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/296/10/approveDate/DESC
#   Requesting page 297 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/297/10/approveDate/DESC
#   Requesting page 298 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/298/10/approveDate/DESC
#   Requesting page 299 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/299/10/approveDate/DESC
#   Requesting page 300 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/300/10/approveDate/DESC
#   Requesting page 301 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/301/10/approveDate/DESC
#   Requesting page 302 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/302/10/approveDate/DESC
#   Requesting page 303 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/303/10/approveDate/DESC
#   Requesting page 304 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/304/10/approveDate/DESC
#   Requesting page 305 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/305/10/approveDate/DESC
#   Requesting page 306 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/306/10/approveDate/DESC
#   Requesting page 307 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/307/10/approveDate/DESC
#   Requesting page 308 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/308/10/approveDate/DESC
#   Requesting page 309 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/309/10/approveDate/DESC
#   Requesting page 310 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/310/10/approveDate/DESC
#   Requesting page 311 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/311/10/approveDate/DESC
#   Requesting page 312 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/312/10/approveDate/DESC
#   Requesting page 313 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/313/10/approveDate/DESC
#   Requesting page 314 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/314/10/approveDate/DESC
#   Requesting page 315 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/315/10/approveDate/DESC
#   Requesting page 316 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/316/10/approveDate/DESC
#   Requesting page 317 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/317/10/approveDate/DESC
#   Requesting page 318 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/318/10/approveDate/DESC
#   Requesting page 319 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/319/10/approveDate/DESC
#   Requesting page 320 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/320/10/approveDate/DESC
#   Requesting page 321 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/321/10/approveDate/DESC
#   Requesting page 322 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/322/10/approveDate/DESC
#   Requesting page 323 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/323/10/approveDate/DESC
#   Requesting page 324 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/324/10/approveDate/DESC
#   Requesting page 325 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/325/10/approveDate/DESC
#   Requesting page 326 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/326/10/approveDate/DESC
#   Requesting page 327 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/327/10/approveDate/DESC
#   Requesting page 328 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/328/10/approveDate/DESC
#   Requesting page 329 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/329/10/approveDate/DESC
#   Requesting page 330 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/330/10/approveDate/DESC
#   Requesting page 331 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/331/10/approveDate/DESC
#   Requesting page 332 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/332/10/approveDate/DESC
#   Requesting page 333 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/333/10/approveDate/DESC
#   Requesting page 334 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/334/10/approveDate/DESC
#   Requesting page 335 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/335/10/approveDate/DESC
#   Requesting page 336 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/336/10/approveDate/DESC
#   Requesting page 337 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/337/10/approveDate/DESC
#   Requesting page 338 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/338/10/approveDate/DESC
#   Requesting page 339 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/339/10/approveDate/DESC
#   Requesting page 340 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/340/10/approveDate/DESC
#   Requesting page 341 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/341/10/approveDate/DESC
#   Requesting page 342 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/342/10/approveDate/DESC
#   Requesting page 343 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/343/10/approveDate/DESC
#   Requesting page 344 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/344/10/approveDate/DESC
#   Requesting page 345 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/345/10/approveDate/DESC
#   Requesting page 346 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/346/10/approveDate/DESC
#   Requesting page 347 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/347/10/approveDate/DESC
#   Requesting page 348 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/348/10/approveDate/DESC
#   Requesting page 349 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/349/10/approveDate/DESC
#   Requesting page 350 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/350/10/approveDate/DESC
#   Requesting page 351 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/351/10/approveDate/DESC
#   Requesting page 352 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/352/10/approveDate/DESC
#   Requesting page 353 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/353/10/approveDate/DESC
#   Requesting page 354 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/354/10/approveDate/DESC
#   Requesting page 355 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/355/10/approveDate/DESC
#   Requesting page 356 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/356/10/approveDate/DESC
#   Requesting page 357 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/357/10/approveDate/DESC
#   Requesting page 358 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/358/10/approveDate/DESC
#   Requesting page 359 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/359/10/approveDate/DESC
#   Requesting page 360 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/360/10/approveDate/DESC
#   Requesting page 361 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/361/10/approveDate/DESC
#   Requesting page 362 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/362/10/approveDate/DESC
#   Requesting page 363 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/363/10/approveDate/DESC
#   Requesting page 364 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/364/10/approveDate/DESC
#   Requesting page 365 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/365/10/approveDate/DESC
#   Requesting page 366 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/366/10/approveDate/DESC
#   Requesting page 367 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/367/10/approveDate/DESC
#   Requesting page 368 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/368/10/approveDate/DESC
#   Requesting page 369 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/369/10/approveDate/DESC
#   Requesting page 370 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/370/10/approveDate/DESC
#   Requesting page 371 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/371/10/approveDate/DESC
#   Requesting page 372 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/372/10/approveDate/DESC
#   Requesting page 373 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/373/10/approveDate/DESC
#   Requesting page 374 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/374/10/approveDate/DESC
#   Requesting page 375 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/375/10/approveDate/DESC
#   Requesting page 376 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/376/10/approveDate/DESC
#   Requesting page 377 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/377/10/approveDate/DESC
#   Requesting page 378 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/378/10/approveDate/DESC
#   Requesting page 379 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/379/10/approveDate/DESC
#   Requesting page 380 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/380/10/approveDate/DESC
#   Requesting page 381 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/381/10/approveDate/DESC
#   Requesting page 382 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/382/10/approveDate/DESC
#   Requesting page 383 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/383/10/approveDate/DESC
#   Requesting page 384 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/384/10/approveDate/DESC
#   Requesting page 385 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/385/10/approveDate/DESC
#   Requesting page 386 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/386/10/approveDate/DESC
#   Requesting page 387 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/387/10/approveDate/DESC
#   Requesting page 388 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/388/10/approveDate/DESC
#   Requesting page 389 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/389/10/approveDate/DESC
#   Requesting page 390 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/390/10/approveDate/DESC
#   Requesting page 391 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/391/10/approveDate/DESC
#   Requesting page 392 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/392/10/approveDate/DESC
#   Requesting page 393 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/393/10/approveDate/DESC
#   Requesting page 394 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/394/10/approveDate/DESC
#   Requesting page 395 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/395/10/approveDate/DESC
#   Requesting page 396 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/396/10/approveDate/DESC
#   Requesting page 397 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/397/10/approveDate/DESC
#   Requesting page 398 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/398/10/approveDate/DESC
#   Requesting page 399 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/399/10/approveDate/DESC
#   Requesting page 400 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/400/10/approveDate/DESC
#   Requesting page 401 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/401/10/approveDate/DESC
#   Requesting page 402 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/402/10/approveDate/DESC
#   Requesting page 403 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/403/10/approveDate/DESC
#   Requesting page 404 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/404/10/approveDate/DESC
#   Requesting page 405 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/405/10/approveDate/DESC
#   Requesting page 406 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/406/10/approveDate/DESC
#   Requesting page 407 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/407/10/approveDate/DESC
#   Requesting page 408 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/408/10/approveDate/DESC
#   Requesting page 409 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/409/10/approveDate/DESC
#   Requesting page 410 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/410/10/approveDate/DESC
#   Requesting page 411 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/411/10/approveDate/DESC
#   Requesting page 412 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/412/10/approveDate/DESC
#   Requesting page 413 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/413/10/approveDate/DESC
#   Requesting page 414 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/414/10/approveDate/DESC
#   Requesting page 415 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/415/10/approveDate/DESC
#   Requesting page 416 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/416/10/approveDate/DESC
#   Requesting page 417 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/417/10/approveDate/DESC
#   Requesting page 418 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/418/10/approveDate/DESC
#   Requesting page 419 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/419/10/approveDate/DESC
#   Requesting page 420 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/420/10/approveDate/DESC
#   Requesting page 421 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/421/10/approveDate/DESC
#   Requesting page 422 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/422/10/approveDate/DESC
#   Requesting page 423 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/423/10/approveDate/DESC
#   Requesting page 424 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/424/10/approveDate/DESC
#   Requesting page 425 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/425/10/approveDate/DESC
#   Requesting page 426 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/426/10/approveDate/DESC
#   Requesting page 427 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/427/10/approveDate/DESC
#   Requesting page 428 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/428/10/approveDate/DESC
#   Requesting page 429 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/429/10/approveDate/DESC
#   Requesting page 430 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/430/10/approveDate/DESC
#   Requesting page 431 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/431/10/approveDate/DESC
#   Requesting page 432 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/432/10/approveDate/DESC
#   Requesting page 433 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/433/10/approveDate/DESC
#   Requesting page 434 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/434/10/approveDate/DESC
#   Requesting page 435 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/435/10/approveDate/DESC
#   Requesting page 436 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/436/10/approveDate/DESC
#   Requesting page 437 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/437/10/approveDate/DESC
#   Requesting page 438 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/438/10/approveDate/DESC
#   Requesting page 439 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/439/10/approveDate/DESC
#   Requesting page 440 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/440/10/approveDate/DESC
#   Requesting page 441 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/441/10/approveDate/DESC
#   Requesting page 442 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/442/10/approveDate/DESC
#   Requesting page 443 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/443/10/approveDate/DESC
#   Requesting page 444 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/444/10/approveDate/DESC
#   Requesting page 445 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/445/10/approveDate/DESC
#   Requesting page 446 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/446/10/approveDate/DESC
#   Requesting page 447 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/447/10/approveDate/DESC
#   Requesting page 448 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/448/10/approveDate/DESC
#   Requesting page 449 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/449/10/approveDate/DESC
#   Requesting page 450 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/450/10/approveDate/DESC
#   Requesting page 451 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/451/10/approveDate/DESC
#   Requesting page 452 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/452/10/approveDate/DESC
#   Requesting page 453 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/453/10/approveDate/DESC
#   Requesting page 454 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/454/10/approveDate/DESC
#   Requesting page 455 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/455/10/approveDate/DESC
#   Requesting page 456 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/456/10/approveDate/DESC
#   Requesting page 457 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/457/10/approveDate/DESC
#   Requesting page 458 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/458/10/approveDate/DESC
#   Requesting page 459 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/459/10/approveDate/DESC
#   Requesting page 460 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/460/10/approveDate/DESC
#   Requesting page 461 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/461/10/approveDate/DESC
#   Requesting page 462 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/462/10/approveDate/DESC
#   Requesting page 463 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/463/10/approveDate/DESC
#   Requesting page 464 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/464/10/approveDate/DESC
#   Requesting page 465 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/465/10/approveDate/DESC
#   Requesting page 466 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/466/10/approveDate/DESC
#   Requesting page 467 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/467/10/approveDate/DESC
#   Requesting page 468 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/468/10/approveDate/DESC
#   Requesting page 469 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/469/10/approveDate/DESC
#   Requesting page 470 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/470/10/approveDate/DESC
#   Requesting page 471 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/471/10/approveDate/DESC
#   Requesting page 472 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/472/10/approveDate/DESC
#   Requesting page 473 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/473/10/approveDate/DESC
#   Requesting page 474 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/474/10/approveDate/DESC
#   Requesting page 475 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/475/10/approveDate/DESC
#   Requesting page 476 from: https://ncar.gov.sa/api/index.php/api/documents/document-search/476/10/approveDate/DESC
#   Error fetching page 476: 500 Server Error: Internal Server Error for url: https://ncar.gov.sa/api/index.php/api/documents/document-search/476/10/approveDate/DESC
#   Failed to retrieve data for this page. Stopping scraping.
# Scraping complete! Total documents scraped: 4750.
# Scraped metadata saved to 'ncar_documents.json'.
# Proceed to the next step to identify the missing files.

# %%
# @title 2. Identify and List Overwritten Files (Run AFTER Step 1 Completes)
import requests
import json
import time
import os
import re
import hashlib
from IPython.display import display, HTML

print("Preparing for collision analysis...")

# Ensure pdf_output_dir exists
pdf_output_dir = "downloaded_pdfs"
if not os.path.exists(pdf_output_dir):
    os.makedirs(pdf_output_dir)

# --- Load Scraped Data (CRUCIAL for this analysis) ---
global all_scraped_data # Ensure it's accessible if not already in global scope from Step 1
if 'all_scraped_data' not in globals() or not all_scraped_data:
    try:
        if os.path.exists("ncar_documents.json"):
            with open("ncar_documents.json", "r", encoding="utf-8") as f:
                all_scraped_data = json.load(f)
            print(f"Loaded {len(all_scraped_data)} documents from 'ncar_documents.json'.")
        else:
            print("Error: 'ncar_documents.json' not found after scraping. Please ensure Step 1 completed successfully.")
            all_scraped_data = [] # Reset to empty to prevent errors
    except Exception as e:
        print(f"An unexpected error occurred while loading data: {e}")
        all_scraped_data = []

# Create a quick lookup for documents by their ID
global document_by_id # Make it global for consistency
document_by_id = {doc['id']: doc for doc in all_scraped_data}

if not all_scraped_data:
    print("No document metadata available. Aborting collision analysis.")
else:
    print(f"Data loaded successfully with {len(all_scraped_data)} documents.")
    print("\nIdentifying documents with potentially duplicate original filenames using the exact observed logic...")

    original_filename_map = {}

    # --- This function perfectly simulates the filename generation from the ORIGINAL download ---
    def simulate_original_filename_logic_from_log(name_part):
        """
        Simulates the original filename sanitization logic observed in the provided log.
        This function is used ONLY for identifying collisions, not for actual file saving.
        """
        try:
            name_part = name_part.encode('latin1').decode('unicode_escape')
        except (UnicodeEncodeError, UnicodeDecodeError):
            pass
        s = re.sub(r'[^\w\s-]', '', name_part).strip()
        s = re.sub(r'[\s]+', '-', s)
        return s

    for doc in all_scraped_data:
        doc_id = doc.get("id")
        if not doc_id:
            continue

        doc_title_en = doc.get("title_en")
        if not doc_title_en:
            doc_title_en = doc.get("title_ar", f"document_no_title_found_{doc_id}")

        doc_number = doc.get("number", "")

        sanitized_title = simulate_original_filename_logic_from_log(doc_title_en)
        sanitized_number = simulate_original_filename_logic_from_log(doc_number)

        original_filename_base_no_id = ""
        if sanitized_number:
            original_filename_base_no_id = f"{sanitized_title}_{sanitized_number}"
        else:
            original_filename_base_no_id = sanitized_title

        final_original_filename_key = f"{original_filename_base_no_id}.pdf"

        if final_original_filename_key in original_filename_map:
            original_filename_map[final_original_filename_key].append(doc_id)
        else:
            original_filename_map[final_original_filename_key] = [doc_id]

    ids_to_redownload_set = set()
    collision_info = []

    for filename_key, doc_ids_list in original_filename_map.items():
        if len(doc_ids_list) > 1:
            ids_to_redownload_set.update(doc_ids_list)
            collision_info.append({
                "filename_key": filename_key,
                "colliding_doc_ids": doc_ids_list,
                "num_collisions": len(doc_ids_list)
            })
            print(f"  Filename '{filename_key}' would have caused {len(doc_ids_list)} collisions.")

    global ids_to_redownload # Make it global for the next download step
    ids_to_redownload = list(ids_to_redownload_set)
    num_unique_filenames_lost = sum(len(ids) - 1 for ids in original_filename_map.values() if len(ids) > 1)

    print(f"\nAnalysis complete. Identified {len(ids_to_redownload)} documents involved in filename collisions.")
    print(f"This indicates approximately {num_unique_filenames_lost} files were overwritten due to shared filenames.")
    print(f"These {len(ids_to_redownload)} documents will be redownloaded with unique filenames.")

    print("\n--- Details of Potentially Overwritten (Missing) Files ---")

    lost_files_count_tracker = 0 # Use a different name to avoid confusion with num_unique_filenames_lost
    if num_unique_filenames_lost == 0:
        print("No filename collisions detected, so no files were likely overwritten due to naming conflicts.")
        print("If you still believe files are missing, the cause might be different (e.g., download errors, API issues).")
    else:
        for collision in collision_info:
            filename = collision["filename_key"]
            colliding_ids = collision["colliding_doc_ids"]

            print(f"\nFilename '{filename}' would have been generated by {len(colliding_ids)} documents:")

            for i, doc_id in enumerate(colliding_ids):
                doc = document_by_id.get(doc_id, {})
                title_en = doc.get('title_en', 'N/A')
                title_ar = doc.get('title_ar', 'N/A')
                number = doc.get('number', 'N/A')

                status_text = "This document would have saved a file with this name (likely the one that remained)."
                if i > 0:
                    status_text = "--> This document's file would have been OVERWRITTEN by a subsequent file with the same name. This is a 'missing' file."
                    lost_files_count_tracker += 1

                print(f"  - Document ID: {doc_id}")
                print(f"    Title (EN): {title_en}")
                print(f"    Title (AR): {title_ar}")
                print(f"    Number: {number}")
                print(f"    {status_text}")
                print("-" * 40)

        print(f"\nTotal estimated files overwritten (net loss of unique filenames): {lost_files_count_tracker}")

    print("\n--- To ensure you have all files with unique names ---")
    print("3. Run the '3. Targeted PDF Redownload with Unique Filenames' cell from the *previous full script response* (the one with the `sanitize_filename_for_unique_save` function).")
    print("4. Then, run the following to download the entire 'downloaded_pdfs' folder:")
    display(HTML("""
    <pre>
    from google.colab import files
    # !zip -r /content/downloaded_pdfs.zip /content/downloaded_pdfs
    files.download('/content/downloaded_pdfs.zip')
    </pre>
    """))
# Out:
# Preparing for collision analysis...
# Data loaded successfully with 4750 documents.
#
# Identifying documents with potentially duplicate original filenames using the exact observed logic...
#   Filename 'تعديل-اسم-برنامج-دعم-التدريب-المرتبط-بالتوظيف-في-المعاهد-غير-الربحية-ليكون-برنامج-دعم-معاهد-الشراكات-الاستراتيجية_1ت21442.pdf' would have caused 2 collisions.
#   Filename 'Circular-regarding-the-implementation-of-IMO-Resolution-96-406-MSC-and-the-amendments-to-the-International-Maritime-Dangerous-Goods-Code_131702579.pdf' would have caused 2 collisions.
#   Filename 'انضمام-وزارة-الشؤون-الإسلامية-والأوقاف-والدعوة-والإرشاد-إلى-اللجنة-الدائمة-لمكافحة-غسل-الأموال_340.pdf' would have caused 2 collisions.
#   Filename 'ترتيبات-تنظيمية-بشأن-بعض-المناطق-التي-قد-تتخذ-للسكنى-لوجود-إشعاعات-اليورانيوم-وغاز-الكبريت-أو-لقربها-من-المنشآت-البترولية_285.pdf' would have caused 2 collisions.
#
# Analysis complete. Identified 8 documents involved in filename collisions.
# This indicates approximately 4 files were overwritten due to shared filenames.
# These 8 documents will be redownloaded with unique filenames.
#
# --- Details of Potentially Overwritten (Missing) Files ---
#
# Filename 'تعديل-اسم-برنامج-دعم-التدريب-المرتبط-بالتوظيف-في-المعاهد-غير-الربحية-ليكون-برنامج-دعم-معاهد-الشراكات-الاستراتيجية_1ت21442.pdf' would have been generated by 2 documents:
#   - Document ID: eyJpdiI6Ii9na1ZsQ0R5NWJUelU5dkU5aURZcUE9PSIsInZhbHVlIjoibDF1TVV1U1ZNNGtlTWxwT21tU2FkUT09IiwibWFjIjoiMWNiZGI2NmY2NTAyY2EwODhhOTVkZGRjYTUyZGIwODMxY2UwMWNiYzFkM2FhZDVkMGJiYTlmYjY2Yjg4NjNiOSIsInRhZyI6IiJ9
#     Title (EN): تعديل اسم برنامج دعم التدريب المرتبط بالتوظيف في المعاهد غير الربحية ليكون برنامج دعم معاهد الشراكات الاستراتيجية
#     Title (AR): تعديل اسم برنامج دعم التدريب المرتبط بالتوظيف في المعاهد غير الربحية ليكون برنامج دعم معاهد الشراكات الاستراتيجية
#     Number: 1/ت/2/1442
#     This document would have saved a file with this name (likely the one that remained).
# ----------------------------------------
#   - Document ID: eyJpdiI6Ilp3eGZ0cXo4aTU4OXJGTEt6VEhSRlE9PSIsInZhbHVlIjoiMHI5R0FhM3hDRzQ0bHJvL0hEbEdJQT09IiwibWFjIjoiZDNlZjVjNzhjMjg1OTNjNTI1MzM3YmQzMTNjODhhYWM0MTM4Y2U1MWUzN2Y0MzNiNGNkZDdiNWNiMzFiZmRiMSIsInRhZyI6IiJ9
#     Title (EN): تعديل اسم برنامج دعم التدريب المرتبط بالتوظيف في المعاهد غير الربحية ليكون برنامج دعم معاهد الشراكات الاستراتيجية
#     Title (AR): تعديل اسم برنامج دعم التدريب المرتبط بالتوظيف في المعاهد غير الربحية ليكون برنامج دعم معاهد الشراكات الاستراتيجية
#     Number: 1/ت/2/1442
#     --> This document's file would have been OVERWRITTEN by a subsequent file with the same name. This is a 'missing' file.
# ----------------------------------------
#
# Filename 'Circular-regarding-the-implementation-of-IMO-Resolution-96-406-MSC-and-the-amendments-to-the-International-Maritime-Dangerous-Goods-Code_131702579.pdf' would have been generated by 2 documents:
#   - Document ID: eyJpdiI6ImZuT1M2SDM0bGNIK28wbHNHRkNOd0E9PSIsInZhbHVlIjoiMGFaSUdOYWxVeXlaWEVLMkIvNlRlZz09IiwibWFjIjoiNjBlM2VjNTI5OTZkMTA4ZTNhMGU4NzkxNTE3NDQxMGZlYjkwZDBhYjJjYmY2ZmNlZmUxNzRhMDJjYzU0YTdkNiIsInRhZyI6IiJ9
#     Title (EN): Circular regarding the implementation of IMO Resolution (96) 406 MSC and the amendments to the International Maritime Dangerous Goods Code
#     Title (AR): تعميم بشأن تطبيق قرار المنظمة البحرية الدولية (96) 406 MSC  وتعديلات المدونة البحرية الدولية للبضائع الخطرة
#     Number: 1/31/70/2579
#     This document would have saved a file with this name (likely the one that remained).
# ----------------------------------------
#   - Document ID: eyJpdiI6IjRGZnZuZVRSZ2JiNzFMcnNVbWkxbUE9PSIsInZhbHVlIjoiM2FoTXFUR2o3OEdxMlRyUUNweWYwQT09IiwibWFjIjoiNmQyYThmNTIyZTQxZjI3NzlhMGI5NzA1ZDFjNDE1NWE5ZTM4NTI5MzE4ZTYwZDc0ZjUwMWM5MWQ4M2ZmNzk4NCIsInRhZyI6IiJ9
#     Title (EN): Circular regarding the implementation of IMO Resolution (96) 406 MSC and the amendments to the International Maritime Dangerous Goods Code
#     Title (AR): تعميم بشأن تطبيق قرار المنظمة البحرية الدولية (96) 406 MSC  وتعديلات المدونة البحرية الدولية للبضائع الخطرة
#     Number: 1/31/70/2579
#     --> This document's file would have been OVERWRITTEN by a subsequent file with the same name. This is a 'missing' file.
# ----------------------------------------
#
# Filename 'انضمام-وزارة-الشؤون-الإسلامية-والأوقاف-والدعوة-والإرشاد-إلى-اللجنة-الدائمة-لمكافحة-غسل-الأموال_340.pdf' would have been generated by 2 documents:
#   - Document ID: eyJpdiI6IkpFaVJuZzhjNmoxVEM1ZzB2dEo3TGc9PSIsInZhbHVlIjoianZuYlJzNUREVENwZHBScVNndXYxUT09IiwibWFjIjoiZDY4MWVjZWE2ZWJmMjM5YWZkMGMyYWQxYTc3ZWY1YzIxNTM5YWUzMjAwN2U4ZjA3MDY1MTAwMDYxYWY4YzIwYSIsInRhZyI6IiJ9
#     Title (EN): انضمام وزارة الشؤون الإسلامية والأوقاف والدعوة والإرشاد إلى اللجنة الدائمة لمكافحة غسل الأموال
#     Title (AR): انضمام وزارة الشؤون الإسلامية والأوقاف والدعوة والإرشاد إلى اللجنة الدائمة لمكافحة غسل الأموال
#     Number: 340
#     This document would have saved a file with this name (likely the one that remained).
# ----------------------------------------
#   - Document ID: eyJpdiI6IjlQYStLajZBYVduZmxRbS9nY0Y2R3c9PSIsInZhbHVlIjoiUFJDUFRlTVNrNXczZkRXV2tlRjdMdz09IiwibWFjIjoiN2VhODg0ZDJhMjdjYzNjZjFiZmNkYzc5NTlmNDcwZWU4YjVmMTc3ZjNjZjRlMmNhN2UyYzVjMTBjNjU1NDYwZiIsInRhZyI6IiJ9
#     Title (EN): انضمام وزارة الشؤون الإسلامية والأوقاف والدعوة والإرشاد إلى اللجنة الدائمة لمكافحة غسل الأموال
#     Title (AR): انضمام وزارة الشؤون الإسلامية والأوقاف والدعوة والإرشاد إلى اللجنة الدائمة لمكافحة غسل الأموال
#     Number: 340
#     --> This document's file would have been OVERWRITTEN by a subsequent file with the same name. This is a 'missing' file.
# ----------------------------------------
#
# Filename 'ترتيبات-تنظيمية-بشأن-بعض-المناطق-التي-قد-تتخذ-للسكنى-لوجود-إشعاعات-اليورانيوم-وغاز-الكبريت-أو-لقربها-من-المنشآت-البترولية_285.pdf' would have been generated by 2 documents:
#   - Document ID: eyJpdiI6Im9KMEV4L1g4Rk43UTAvYW5pZTVPdUE9PSIsInZhbHVlIjoieEFPMVdFN1dWV3ltdDhaLyt0UGV6Zz09IiwibWFjIjoiNjY1NWI1ZDhiNWE3NDE1ZmFhNmI4OWI3YTBmNmVhYzI1NTcwNzViMDFiYWY2NTAxZGJmNDMwMTFkYTM5OWMzNyIsInRhZyI6IiJ9
#     Title (EN): ترتيبات تنظيمية بشأن بعض المناطق التي قد تتخذ للسكنى لوجود إشعاعات اليورانيوم وغاز الكبريت أو لقربها من المنشآت البترولية
#     Title (AR): ترتيبات تنظيمية بشأن بعض المناطق التي قد تتخذ للسكنى لوجود إشعاعات اليورانيوم وغاز الكبريت أو لقربها من المنشآت البترولية
#     Number: 285
#     This document would have saved a file with this name (likely the one that remained).
# ----------------------------------------
#   - Document ID: eyJpdiI6IjVFTjlxU3E5ZzRnWHJqamNZS3ppdXc9PSIsInZhbHVlIjoiZitHcVhybDFYc3JHVjBvbHdmY3Nndz09IiwibWFjIjoiNDAxZDkxMTA3NTUxNzQ1YzYxMmZjZDk3ZTVlMDI0Y2MxNDI1YzcxNWQ1ZDI2NzEwYmI1NDgzMWRkOTUxZWM2YiIsInRhZyI6IiJ9
#     Title (EN): ترتيبات تنظيمية بشأن بعض المناطق التي قد تتخذ للسكنى لوجود إشعاعات اليورانيوم وغاز الكبريت أو لقربها من المنشآت البترولية
#     Title (AR): ترتيبات تنظيمية بشأن بعض المناطق التي قد تتخذ للسكنى لوجود إشعاعات اليورانيوم وغاز الكبريت أو لقربها من المنشآت البترولية
#     Number: 285
#     --> This document's file would have been OVERWRITTEN by a subsequent file with the same name. This is a 'missing' file.
# ----------------------------------------
#
# Total estimated files overwritten (net loss of unique filenames): 4
#
# --- To ensure you have all files with unique names ---
# 3. Run the '3. Targeted PDF Redownload with Unique Filenames' cell from the *previous full script response* (the one with the `sanitize_filename_for_unique_save` function).
# 4. Then, run the following to download the entire 'downloaded_pdfs' folder:
#     <pre>
#     from google.colab import files
#     !zip -r /content/downloaded_pdfs.zip /content/downloaded_pdfs
#     files.download('/content/downloaded_pdfs.zip')
#     </pre>

# %%
# @title Identify and List Overwritten Files (Revised with imports)
import requests
import json
import time
import os
import re
import hashlib
from IPython.display import display, HTML

print("Setting up environment and loading data for collision analysis...")

# Ensure pdf_output_dir exists, as expected by the sanitize function later
pdf_output_dir = "downloaded_pdfs"
if not os.path.exists(pdf_output_dir):
    os.makedirs(pdf_output_dir)

# --- Load Scraped Data (CRUCIAL for this analysis) ---
all_scraped_data = []
document_by_id = {}
try:
    if os.path.exists("ncar_documents.json"):
        with open("ncar_documents.json", "r", encoding="utf-8") as f:
            all_scraped_data = json.load(f)
        print(f"Loaded {len(all_scraped_data)} documents from 'ncar_documents.json'.")
        document_by_id = {doc['id']: doc for doc in all_scraped_data}
    else:
        print("Error: 'ncar_documents.json' not found. Please ensure you have run the '2. Scraping All Document Metadata' cell from the full script in your Colab session, which saves this file. This analysis cannot proceed without the full metadata.")
        # If the file isn't found, this script won't be able to perform the analysis.
        # We'll proceed with empty data, but the user needs to know.
except Exception as e:
    print(f"An unexpected error occurred while loading data: {e}")
    print("Please ensure 'ncar_documents.json' is correctly saved and accessible.")

if not all_scraped_data:
    print("No document metadata available. Aborting collision analysis.")
else:
    print(f"Data loaded successfully with {len(all_scraped_data)} documents.")
    print("\nIdentifying documents with potentially duplicate original filenames using the exact observed logic...")

    original_filename_map = {}

    # --- This function perfectly simulates the filename generation from the ORIGINAL download ---
    def simulate_original_filename_logic_from_log(name_part):
        """
        Simulates the original filename sanitization logic observed in the provided log.
        This function is used ONLY for identifying collisions, not for actual file saving.
        """
        # Decode potential Unicode escape sequences (e.g., from Arabic characters)
        try:
            name_part = name_part.encode('latin1').decode('unicode_escape')
        except (UnicodeEncodeError, UnicodeDecodeError):
            pass # If not a unicode escape sequence, keep as is

        # Remove characters that are not letters, numbers, hyphens, underscores, or spaces
        s = re.sub(r'[^\w\s-]', '', name_part).strip()
        # Replace multiple spaces with a single hyphen
        s = re.sub(r'[\s]+', '-', s)
        return s

    for doc in all_scraped_data:
        doc_id = doc.get("id")
        if not doc_id:
            continue

        doc_title_en = doc.get("title_en")
        if not doc_title_en:
            doc_title_en = doc.get("title_ar", f"document_no_title_found_{doc_id}")

        doc_number = doc.get("number", "")

        sanitized_title = simulate_original_filename_logic_from_log(doc_title_en)
        sanitized_number = simulate_original_filename_logic_from_log(doc_number)

        original_filename_base_no_id = ""
        if sanitized_number:
            original_filename_base_no_id = f"{sanitized_title}_{sanitized_number}"
        else:
            original_filename_base_no_id = sanitized_title

        final_original_filename_key = f"{original_filename_base_no_id}.pdf"

        if final_original_filename_key in original_filename_map:
            original_filename_map[final_original_filename_key].append(doc_id)
        else:
            original_filename_map[final_original_filename_key] = [doc_id]

    ids_to_redownload_set = set()
    collision_info = []

    for filename_key, doc_ids_list in original_filename_map.items():
        if len(doc_ids_list) > 1:
            ids_to_redownload_set.update(doc_ids_list)
            collision_info.append({
                "filename_key": filename_key,
                "colliding_doc_ids": doc_ids_list,
                "num_collisions": len(doc_ids_list)
            })
            print(f"  Filename '{filename_key}' would have caused {len(doc_ids_list)} collisions.")

    ids_to_redownload = list(ids_to_redownload_set)
    num_unique_filenames_lost = sum(len(ids) - 1 for ids in original_filename_map.values() if len(ids) > 1)

    print(f"\nAnalysis complete. Identified {len(ids_to_redownload)} documents involved in filename collisions.")
    print(f"This indicates approximately {num_unique_filenames_lost} files were overwritten due to shared filenames.")
    print(f"These {len(ids_to_redownload)} documents will be redownloaded with unique filenames.")

    # Now, identify the specific files that were "lost" (all but one in each collision group)
    print("\n--- Details of Potentially Overwritten (Missing) Files ---")

    lost_files_count = 0
    if num_unique_filenames_lost == 0:
        print("No filename collisions detected, so no files were likely overwritten due to naming conflicts.")
        print("If you still believe files are missing, the cause might be different (e.g., download errors, API issues).")
    else:
        for collision in collision_info:
            filename = collision["filename_key"]
            colliding_ids = collision["colliding_doc_ids"]

            print(f"\nFilename '{filename}' would have been generated by {len(colliding_ids)} documents:")

            for i, doc_id in enumerate(colliding_ids):
                doc = document_by_id.get(doc_id, {})
                title_en = doc.get('title_en', 'N/A')
                title_ar = doc.get('title_ar', 'N/A')
                number = doc.get('number', 'N/A')

                status_text = "This document would have saved a file with this name (likely the one that remained)."
                if i > 0:
                    status_text = "--> This document's file would have been OVERWRITTEN by a subsequent file with the same name. This is a 'missing' file."
                    lost_files_count += 1

                print(f"  - Document ID: {doc_id}")
                print(f"    Title (EN): {title_en}")
                print(f"    Title (AR): {title_ar}")
                print(f"    Number: {number}")
                print(f"    {status_text}")
                print("-" * 40)

        print(f"\nTotal estimated files overwritten (net loss of unique filenames): {lost_files_count}")

    # Final reminder about downloading the fixed files
    print("\n--- To ensure you have all files with unique names ---")
    print("1. Run the '3. Targeted PDF Redownload with Unique Filenames' cell from the previous response.")
    print("2. Then, run the following to download the entire 'downloaded_pdfs' folder:")
    display(HTML("""
    <pre>
    from google.colab import files
    # !zip -r /content/downloaded_pdfs.zip /content/downloaded_pdfs
    files.download('/content/downloaded_pdfs.zip')
    </pre>
    """))
# Out:
# Setting up environment and loading data for collision analysis...
# Loaded 530 documents from 'ncar_documents.json'.
# Data loaded successfully with 530 documents.
#
# Identifying documents with potentially duplicate original filenames using the exact observed logic...
#
# Analysis complete. Identified 0 documents involved in filename collisions.
# This indicates approximately 0 files were overwritten due to shared filenames.
# These 0 documents will be redownloaded with unique filenames.
#
# --- Details of Potentially Overwritten (Missing) Files ---
# No filename collisions detected, so no files were likely overwritten due to naming conflicts.
# If you still believe files are missing, the cause might be different (e.g., download errors, API issues).
#
# --- To ensure you have all files with unique names ---
# 1. Run the '3. Targeted PDF Redownload with Unique Filenames' cell from the previous response.
# 2. Then, run the following to download the entire 'downloaded_pdfs' folder:
#     <pre>
#     from google.colab import files
#     !zip -r /content/downloaded_pdfs.zip /content/downloaded_pdfs
#     files.download('/content/downloaded_pdfs.zip')
#     </pre>

# %%
# @title 3. Targeted PDF Redownload with Unique Filenames

print("\nStarting targeted PDF redownload...")

# Base URL parts for PDF resources
base_pdf_url_prefix = "https://ncar.gov.sa/api/index.php/resource/"
base_pdf_url_suffix = "/Documents/OriginalAttachPath"

downloaded_this_run_count = 0
total_to_redownload = len(ids_to_redownload) # This list is populated by the previous cell

if total_to_redownload == 0:
    print("No documents identified for targeted redownload based on collision analysis.")
    print("If you still believe files are missing, please double-check 'all_scraped_data' integrity.")
elif not all_scraped_data:
    print("Cannot proceed with download: 'all_scraped_data' is empty. Please run the scraping cell or load from JSON.")
else:
    for i, doc_id_to_redownload in enumerate(ids_to_redownload):
        doc = document_by_id.get(doc_id_to_redownload) # Get the full document object using the global lookup
        if not doc:
            print(f"  Warning: Document with ID '{doc_id_to_redownload}' not found in scraped data. Skipping.")
            continue

        encrypted_part = doc.get("id")
        if not encrypted_part:
            print(f"  Skipping document ID '{doc_id_to_redownload}': No encrypted part found.")
            continue

        pdf_url = f"{base_pdf_url_prefix}{encrypted_part}{base_pdf_url_suffix}"

        # Generate filename using the NEW, unique sanitize_filename_for_unique_save function
        doc_title_en = doc.get("title_en")
        if not doc_title_en:
            doc_title_en = doc.get("title_ar", f"document_no_title_{doc_id_to_redownload}")

        doc_number = doc.get("number", "")

        # Combine title and number for the base part of the unique filename
        combined_name_for_unique = f"{doc_title_en}"
        if doc_number:
            combined_name_for_unique += f"_{doc_number}"

        filename_base = sanitize_filename_for_unique_save(combined_name_for_unique, doc_id_to_redownload)
        pdf_filename = os.path.join(pdf_output_dir, f"{filename_base}.pdf")

        # Check if a file with this *exact unique name* already exists before downloading
        if os.path.exists(pdf_filename):
            print(f"  File already exists with unique name: '{pdf_filename}'. Skipping download.")
            downloaded_this_run_count += 1 # Count it as "found"
            continue

        print(f"  Redownloading ({i+1}/{total_to_redownload}): '{filename_base}'")

        headers = {
            "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36",
            "Referer": "https://ncar.gov.sa/rules-regulations"
        }

        try:
            with requests.get(pdf_url, headers=headers, stream=True) as r:
                r.raise_for_status()

                content_type = r.headers.get('Content-Type', '')
                if 'application/pdf' not in content_type and 'octet-stream' not in content_type:
                    print(f"    Warning: Expected PDF for '{filename_base}', but got Content-Type: '{content_type}'. Skipping.")
                    continue

                with open(pdf_filename, 'wb') as f:
                    for chunk in r.iter_content(chunk_size=8192):
                        f.write(chunk)
                print(f"    Successfully saved: '{pdf_filename}'")
                downloaded_this_run_count += 1

        except requests.exceptions.RequestException as e:
            print(f"    Error downloading '{filename_base}': {e}")
        except Exception as e:
            print(f"    An unexpected error occurred for '{filename_base}': {e}")

        time.sleep(0.5) # Polite delay

print(f"\nTargeted redownload complete! PDFs downloaded in this run: {downloaded_this_run_count}.")
print("The new files will have a unique suffix (e.g., '_abcdef12.pdf') to prevent future conflicts.")

# Optional: Download all your PDFs again (if you want the new ones + existing ones)
print("\n---")
print("To download ALL your PDFs (including newly added ones), run the following in a new Colab cell:")
display(HTML("""
<pre>
from google.colab import files
# !zip -r /content/downloaded_pdfs.zip /content/downloaded_pdfs
files.download('/content/downloaded_pdfs.zip')
</pre>
"""))
# Out:
# Starting targeted PDF redownload...
#   Redownloading (1/8): 'ترتيبات-تنظيمية-بشأن-بعض-المناطق-التي-قد-تتخذ-للسكنى-لوجود-إشعاعات-اليورانيوم-وغ_e2b5a250'
#     Successfully saved: 'downloaded_pdfs/ترتيبات-تنظيمية-بشأن-بعض-المناطق-التي-قد-تتخذ-للسكنى-لوجود-إشعاعات-اليورانيوم-وغ_e2b5a250.pdf'
#   Redownloading (2/8): 'Circular-regarding-the-implementation-of-IMO-Resolution-96-406-MSC-and-the-amend_ad6c5e8e'
#     Successfully saved: 'downloaded_pdfs/Circular-regarding-the-implementation-of-IMO-Resolution-96-406-MSC-and-the-amend_ad6c5e8e.pdf'
#   Redownloading (3/8): 'Circular-regarding-the-implementation-of-IMO-Resolution-96-406-MSC-and-the-amend_7a606064'
#     Successfully saved: 'downloaded_pdfs/Circular-regarding-the-implementation-of-IMO-Resolution-96-406-MSC-and-the-amend_7a606064.pdf'
#   Redownloading (4/8): 'انضمام-وزارة-الشؤون-الإسلامية-والأوقاف-والدعوة-والإرشاد-إلى-اللجنة-الدائمة-لمكاف_0fb17411'
#     Successfully saved: 'downloaded_pdfs/انضمام-وزارة-الشؤون-الإسلامية-والأوقاف-والدعوة-والإرشاد-إلى-اللجنة-الدائمة-لمكاف_0fb17411.pdf'
#   Redownloading (5/8): 'تعديل-اسم-برنامج-دعم-التدريب-المرتبط-بالتوظيف-في-المعاهد-غير-الربحية-ليكون-برنام_8789c70f'
#     Successfully saved: 'downloaded_pdfs/تعديل-اسم-برنامج-دعم-التدريب-المرتبط-بالتوظيف-في-المعاهد-غير-الربحية-ليكون-برنام_8789c70f.pdf'
#   Redownloading (6/8): 'ترتيبات-تنظيمية-بشأن-بعض-المناطق-التي-قد-تتخذ-للسكنى-لوجود-إشعاعات-اليورانيوم-وغ_c7b860ae'
#     Successfully saved: 'downloaded_pdfs/ترتيبات-تنظيمية-بشأن-بعض-المناطق-التي-قد-تتخذ-للسكنى-لوجود-إشعاعات-اليورانيوم-وغ_c7b860ae.pdf'
#   Redownloading (7/8): 'تعديل-اسم-برنامج-دعم-التدريب-المرتبط-بالتوظيف-في-المعاهد-غير-الربحية-ليكون-برنام_f3754ff4'
#     Successfully saved: 'downloaded_pdfs/تعديل-اسم-برنامج-دعم-التدريب-المرتبط-بالتوظيف-في-المعاهد-غير-الربحية-ليكون-برنام_f3754ff4.pdf'
#   Redownloading (8/8): 'انضمام-وزارة-الشؤون-الإسلامية-والأوقاف-والدعوة-والإرشاد-إلى-اللجنة-الدائمة-لمكاف_7b840ea4'
#     Successfully saved: 'downloaded_pdfs/انضمام-وزارة-الشؤون-الإسلامية-والأوقاف-والدعوة-والإرشاد-إلى-اللجنة-الدائمة-لمكاف_7b840ea4.pdf'
#
# Targeted redownload complete! PDFs downloaded in this run: 8.
# The new files will have a unique suffix (e.g., '_abcdef12.pdf') to prevent future conflicts.
#
# ---
# To download ALL your PDFs (including newly added ones), run the following in a new Colab cell:
# <pre>
# from google.colab import files
# !zip -r /content/downloaded_pdfs.zip /content/downloaded_pdfs
# files.download('/content/downloaded_pdfs.zip')
# </pre>
